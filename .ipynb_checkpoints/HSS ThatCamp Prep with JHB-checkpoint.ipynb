# %%
from tethne.readers import wos

# %%
wos_corpus = wos.read('/Users/erickpeirson/Downloads/JHB from JSTOR/wos')

# %%
len(wos_corpus)
# Out:
# 1168

# %%
from tethne.networks import coauthors, cocitation

# %%
ca = coauthors(wos_corpus)

# %%
ca.order(), ca.size()
# Out:
# (137, 96)

# %%
from tethne import GraphCollection

# %%
GCA = GraphCollection(wos_corpus, coauthors, slice_kwargs={"window_size": 4, 'step_size': 1})

# %%
GCA.order(), GCA.size()
# Out:
# (137, 371)

# %%
from tethne import LDAModel, tokenize

# %%
wos_corpus.index_feature('abstract', tokenize=tokenize, structured=True)

# %%
from nltk.corpus import stopwords
stoplist = stopwords.words()

# %%
def apply_stoplist(f, v, c, dc):
    def number(v):
        try:
            eval(v)
            return True
        except:
            return False
                
    if f.lower() in stoplist or dc > 50 or dc < 3 or number(f) or len(f) < 4:
        return None
    return v

# %%
wos_corpus.features['abstract_filtered'] = wos_corpus.features['abstract'].transform(apply_stoplist)

# %%
model = LDAModel(wos_corpus, featureset_name='abstract_filtered')

# %%
model.fit(Z=50, max_iter=500)

# %%
model.print_topics()
# Out:
# Topic	Top 10 words
# 0  	political society popular response position sociobiology classification hand figure offered
# 1  	debate significant question origins great humans nuclear prominent radiation connection
# 2  	genetic organisms systems specific information genes provided virus gene effects
# 3  	project princeton medical results atomic energy primarily describes production potential
# 4  	theories technol status geneticists richard difference morgan reasons conducted conception
# 5  	questions nineteenth number taxonomy museum received systematics involved european technical
# 6  	authors eugenics racial eugenic present perspective diversity strong nazi rats
# 7  	variation developmental argued individual light processes main weismann stage weismanns
# 8  	heredity inheritance hereditary explain characteristics found characters distinct acquired elements
# 9  	plant focus examines alternative applied fundamental ideal half disciplines decades
# 10 	context institute postwar special japanese hybrid mexican interaction corn dynamic
# 11 	cell researchers material cells eventually objects chemical protein claim made
# 12 	german order morphology england progress interpretation attempt organic manchester conceptual
# 13 	argue modern idea types darwinism chicago economy shared journal decades
# 14 	naturalists related called discussions individuals relationships writings detailed beagle collecting
# 15 	forms period politics transformation turn interest understood experimentation reaction pittsburgh
# 16 	essay united states growth sites examining washington resources features activities
# 17 	synthesis hypothesis explanation view major ultimately mitchell london biol enzyme
# 18 	practice community professional academic relationship literature amateurs victorian liberal goals
# 19 	understanding developed group explores relations argued movement place essential provided
# 20 	techniques issues focusing biochemical technology biochemistry department ways reflected technol
# 21 	population understand suggests framework education concerns mayr movement models conflict
# 22 	public impact contributed case publication observations england fact making colonial
# 23 	influence personal considered contributions interactions contemporary basis moral claims workers
# 24 	animal animals show behavior provide methodological primate attention systematic radford
# 25 	historians evidence views importance laws emphasis thinking principles articles conclusions
# 26 	works term broader identification investigations soil published discoveries proposed chemistry
# 27 	including environment support today prior place interested accounts calif director
# 28 	methods agricultural point developed germany statistical disciplines student significance tech
# 29 	biol data record generation huxley sense link arizona fossil past
# 30 	knowledge made sexual published organisms theoretical accepted papers reception robert
# 31 	practices inst wallace berlin germany groups story helped contrast shaped
# 32 	breeding breeders practical world mendelism agricultural artificial true unit humanities
# 33 	mexico physiology played physiological argues physiologists culture perception discipline visual
# 34 	origin ideas charles form thought presented aristotles famous issue letter
# 35 	university institutional school national international agriculture vision europe biophysics universities
# 36 	process discipline darwinian revolution intellectual examination strategies professionalization investigation culture
# 37 	concept concepts french france notion language tradition paris giraffe physical
# 38 	ecology ecological local large shows controversy vegetation committee areas members
# 39 	based patterns elements recent explanations implications experience recognized mcclintock lineage
# 40 	factors studying regeneration aging path epistemic broad remained approaches marine
# 41 	attention central western cultural china efforts america soviet power cold
# 42 	account scientist generally theoretical discusses variety clements interests approach organism
# 43 	south environmental began change management world control conservation national africa
# 44 	general problems method living philosophical similar experiment canada things problem
# 45 	late discovery experiments cancer episode vivisection lack search biomedical blood
# 46 	case success established netherlands worked women colleagues make environments philosophers
# 47 	british coll william cambridge scholars toronto writing parts views division
# 48 	series book comparative lectures working anderson major establishment columbia publications
# 49 	view system change trees shift mechanism edition created mendelian text

# %%
from tethne.networks.topics import topic_coupling, terms, cotopics

# %%
tc = topic_coupling(model)

# %%
tc.order(), tc.size()
# Out:
# (299, 3599)

# %%
tr = terms(model)
tr.order(), tr.size()
# Out:
# (1414, 24857)

# %%
ct = cotopics(model)
ct.order(), ct.size()
# Out:
# (50, 1017)

# %%
model.M = model.Z

# %%
from tethne.readers import dfr

# %%
dfr_corpus = dfr.read('/Users/erickpeirson/JHB/data/DfR')

# %%
len(dfr_corpus)

# %%
corpus.features

# %%
from tethne.readers import merge

# %%
corpus = merge(wos_corpus, dfr_corpus)

# %%
len(corpus)
# Out:
# 1627

# %%
corpus[('authors', ('BENNETT', 'BRETT M'))][0].__dict__
# Out:
# {'ER': u'',
#  'FX': [u'I would like to thank the outside reviewers who critiqued this article',
#   u'and offered many useful comments. Jane and Libby gave invaluable advice',
#   u'and constant help during the revision process. The Centre for',
#   u'Environmental History and the History Program at the Australian National',
#   u'University provided me with office space and an intellectual home away',
#   u'from home that allowed me to revise this article for publication. I',
#   u'would also like to acknowledge the Social Science Research Council and',
#   u'the American Council of Learned Societies for funding my International',
#   u'Dissertation Research Fellowship, which allowed me to pursue archival',
#   u'research for this article in Australia, South Africa, and the United',
#   u'Kingdom.'],
#  'GA': u'739JW',
#  'ISSN': [u'0022-5010', u'J9 J HIST BIOL'],
#  'PD': u'FEB',
#  'PG': 21,
#  'PM': 20665086,
#  'PT': u'J',
#  'WC': u'Biology; History & Philosophy Of Science',
#  'abstract': u'Scholars studying the globalization of Australian trees have previously emphasized the rapid natural propagation of Australian trees outside of their native habitats, believing their success to be a reversal of "ecological imperialism" from the "new world" to the "old world." This article argues that the expansion of Australian trees should not be viewed as a biological phenomenon, but as the result of a long-term attempt by powerful states and state-sponsored scientists to select and breed Australian species that could grow in a variety of climates and ecological conditions. Five non-biological factors largely determined the success of these attempts to grow Australian trees: the abundance or paucity of natural forests, state power, the amount of scientific research directed to planting Australian trees, the cost of labor, and the ability to utilize hardwood timbers and bark. This paper compares the use of Australian trees in Australia, India, and South Africa to demonstrate that biology was not the determining factor in the long-term success of many Australian genera and species. C1 Univ Western Sydney, Sch Humanities & Languages, Sydney, NSW, Australia.',
#  'authorKeywords': [u'ACACIA', u'IMPERIALISM'],
#  'authors_full': [(u'BENNETT', u'BRETT M')],
#  'authors_init': [(u'BENNETT', u'B M')],
#  'citationCount': 80,
#  'citedReferences': [<tethne.classes.paper.Paper at 0x10a025fd0>,
#   <tethne.classes.paper.Paper at 0x10a034090>,
#   <tethne.classes.paper.Paper at 0x10a0348d0>,
#   <tethne.classes.paper.Paper at 0x10a034910>,
#   <tethne.classes.paper.Paper at 0x10a034950>,
#   <tethne.classes.paper.Paper at 0x10a0349d0>,
#   <tethne.classes.paper.Paper at 0x10a034990>,
#   <tethne.classes.paper.Paper at 0x10a034a10>,
#   <tethne.classes.paper.Paper at 0x10a034a50>,
#   <tethne.classes.paper.Paper at 0x10a034a90>,
#   <tethne.classes.paper.Paper at 0x10a034ad0>,
#   <tethne.classes.paper.Paper at 0x10a034b10>,
#   <tethne.classes.paper.Paper at 0x10a034b50>,
#   <tethne.classes.paper.Paper at 0x10a034b90>,
#   <tethne.classes.paper.Paper at 0x10a034bd0>,
#   <tethne.classes.paper.Paper at 0x10a034c10>,
#   <tethne.classes.paper.Paper at 0x10a034c50>,
#   <tethne.classes.paper.Paper at 0x10a034c90>,
#   <tethne.classes.paper.Paper at 0x10a034cd0>,
#   <tethne.classes.paper.Paper at 0x10a034d10>,
#   <tethne.classes.paper.Paper at 0x10a034d50>,
#   <tethne.classes.paper.Paper at 0x10a034d90>,
#   <tethne.classes.paper.Paper at 0x10a034dd0>,
#   <tethne.classes.paper.Paper at 0x10a034e10>,
#   <tethne.classes.paper.Paper at 0x10a034e90>,
#   <tethne.classes.paper.Paper at 0x10a034e50>,
#   <tethne.classes.paper.Paper at 0x10a034ed0>,
#   <tethne.classes.paper.Paper at 0x10a034f10>,
#   <tethne.classes.paper.Paper at 0x10a034f50>,
#   <tethne.classes.paper.Paper at 0x10a034f90>,
#   <tethne.classes.paper.Paper at 0x10a034fd0>,
#   <tethne.classes.paper.Paper at 0x10a041090>,
#   <tethne.classes.paper.Paper at 0x10a041050>,
#   <tethne.classes.paper.Paper at 0x10a0410d0>,
#   <tethne.classes.paper.Paper at 0x10a041110>,
#   <tethne.classes.paper.Paper at 0x10a041150>,
#   <tethne.classes.paper.Paper at 0x10a041190>,
#   <tethne.classes.paper.Paper at 0x10a0411d0>,
#   <tethne.classes.paper.Paper at 0x10a041210>,
#   <tethne.classes.paper.Paper at 0x10a041250>,
#   <tethne.classes.paper.Paper at 0x10a0412d0>,
#   <tethne.classes.paper.Paper at 0x10a041290>,
#   <tethne.classes.paper.Paper at 0x10a041310>,
#   <tethne.classes.paper.Paper at 0x10a041350>,
#   <tethne.classes.paper.Paper at 0x10a041390>,
#   <tethne.classes.paper.Paper at 0x10a041410>,
#   <tethne.classes.paper.Paper at 0x10a041450>,
#   <tethne.classes.paper.Paper at 0x10a041490>,
#   <tethne.classes.paper.Paper at 0x10a0414d0>,
#   <tethne.classes.paper.Paper at 0x10a041510>,
#   <tethne.classes.paper.Paper at 0x10a041590>,
#   <tethne.classes.paper.Paper at 0x10a0415d0>,
#   <tethne.classes.paper.Paper at 0x10a041550>,
#   <tethne.classes.paper.Paper at 0x10a041610>,
#   <tethne.classes.paper.Paper at 0x10a041650>,
#   <tethne.classes.paper.Paper at 0x10a041690>,
#   <tethne.classes.paper.Paper at 0x10a0416d0>,
#   <tethne.classes.paper.Paper at 0x10a041710>,
#   <tethne.classes.paper.Paper at 0x10a041750>,
#   <tethne.classes.paper.Paper at 0x10a041790>,
#   <tethne.classes.paper.Paper at 0x10a0417d0>,
#   <tethne.classes.paper.Paper at 0x10a041810>,
#   <tethne.classes.paper.Paper at 0x10a041850>,
#   <tethne.classes.paper.Paper at 0x10a0418d0>,
#   <tethne.classes.paper.Paper at 0x10a041890>,
#   <tethne.classes.paper.Paper at 0x10a041910>,
#   <tethne.classes.paper.Paper at 0x10a041950>,
#   <tethne.classes.paper.Paper at 0x10a041990>,
#   <tethne.classes.paper.Paper at 0x10a0419d0>,
#   <tethne.classes.paper.Paper at 0x10a041a10>,
#   <tethne.classes.paper.Paper at 0x10a041a50>,
#   <tethne.classes.paper.Paper at 0x10a041a90>,
#   <tethne.classes.paper.Paper at 0x10a041ad0>,
#   <tethne.classes.paper.Paper at 0x10a041b10>,
#   <tethne.classes.paper.Paper at 0x10a041b90>,
#   <tethne.classes.paper.Paper at 0x10a041c10>,
#   <tethne.classes.paper.Paper at 0x10a041bd0>,
#   <tethne.classes.paper.Paper at 0x10a041c50>,
#   <tethne.classes.paper.Paper at 0x10a041b50>,
#   <tethne.classes.paper.Paper at 0x10a041c90>],
#  'date': 2011,
#  'documentType': u'Article',
#  'doi': u'10.1007/s10739-010-9243-7',
#  'emailAddress': u'utxaustinbennett@yahoo.com',
#  'funding': [(u'Social Science Research Council', None),
#   (u'American Council of Learned Societies', None)],
#  'isoSource': u'J. Hist. Biol.',
#  'issue': 1,
#  'journal': u'JOURNAL OF THE HISTORY OF BIOLOGY',
#  'keywordsPlus': [u'Acacia; ecological imperialism; Eucalyptus; forestry; globalization;',
#   u'invasive species; plantation; silviculture'],
#  'language': u'English',
#  'pageEnd': 145,
#  'pageStart': 125,
#  'publisher': u'SPRINGER',
#  'publisherAddress': u'VAN GODEWIJCKSTRAAT 30, 3311 GZ DORDRECHT, NETHERLANDS',
#  'publisherCity': u'DORDRECHT',
#  'reprintAddress': u'Bennett, BM (reprint author), Univ Western Sydney, Sch Humanities & Languages, Sydney, NSW, Australia.',
#  'subject': [u'Life Sciences & Biomedicine - Other Topics; History & Philosophy of',
#   u'Science'],
#  'timesCited': [9, u'Z9 10'],
#  'title': u'A Global History Of Australian Trees',
#  'volume': u'44',
#  'wosid': u'WOS:000288714200007'}

# %%
from tethne.readers import merge

# %%
combined = Corpus(merge(corpus.papers, dfr_corpus_combined))

# %%
combined.indexed_papers
# Out:
# {'d50874c16256f93dc5e71dbb9ca310e3': <tethne.classes.paper.Paper at 0x10db01190>,
#  '62f046d9e8d4d1f94ab96fc34cfb06b8': <tethne.classes.paper.Paper at 0x10d825a10>,
#  '7eeaec917f401e7d687599d8fff797a2': <tethne.classes.paper.Paper at 0x10d7c9f10>,
#  'ca86e7c02d91a78f4bc7954fa6972ce0': <tethne.classes.paper.Paper at 0x10d8a5090>,
#  '55a71aa1fe8c913ade4e7e215b02761c': <tethne.classes.paper.Paper at 0x10defb3d0>,
#  '2bbbfd27cf14d3b20f3bec5fba5e4b04': <tethne.classes.paper.Paper at 0x10dd6f610>,
#  '8c8fa018354322ea054ee46f839e991f': <tethne.classes.paper.Paper at 0x10da60210>,
#  'cf41f4f27c6e07c0d6e90479a4ae95b7': <tethne.classes.paper.Paper at 0x1103978d0>,
#  '3f51cbf641398f433dd58e0efc089f93': <tethne.classes.paper.Paper at 0x11564cbd0>,
#  '539922b743fa5529d54e54d925c8be93': <tethne.classes.paper.Paper at 0x10d73c1d0>,
#  '1d99909cb89c74cf18ec9e19452e516a': <tethne.classes.paper.Paper at 0x10dced950>,
#  '167963ed4d67021b870b6492cb0abd9f': <tethne.classes.paper.Paper at 0x11e84a9d0>,
#  'a5cd2b4b716cbf33c03c322dd4db7c8f': <tethne.classes.paper.Paper at 0x11d0a6c50>,
#  '6045aae4812d1c1c77a05a8968bf8a4f': <tethne.classes.paper.Paper at 0x11d0a6790>,
#  'e8824871939ec0bb1e4647c3590e3e5c': <tethne.classes.paper.Paper at 0x10db85b50>,
#  '6d1dd98db8ad22ab8fcf879ef184d8d1': <tethne.classes.paper.Paper at 0x10d7d3650>,
#  '10a12ec55592d85fc973c69233d6d35b': <tethne.classes.paper.Paper at 0x11e84a090>,
#  '3a1777df35f4ab632b7b2141ac62b539': <tethne.classes.paper.Paper at 0x10da605d0>,
#  'ec1a47d093c9641de33ba8413fb15dc6': <tethne.classes.paper.Paper at 0x10da60350>,
#  'b16e200b261d87edbea2ce4b0b014b36': <tethne.classes.paper.Paper at 0x10da03950>,
#  '3d392a0b04208e58abccc75127f15301': <tethne.classes.paper.Paper at 0x10d7c9f50>,
#  '5f298b80655552f6d3d82131d4d7226a': <tethne.classes.paper.Paper at 0x10d825dd0>,
#  '7faa314d6b2b3bd294f006ad1348b118': <tethne.classes.paper.Paper at 0x120002150>,
#  '38527bf7d4937e4c680c0650462d34f2': <tethne.classes.paper.Paper at 0x10db20990>,
#  '4a456dfe6f47b70f925da1d7565a287a': <tethne.classes.paper.Paper at 0x10d7c9a10>,
#  '281c5d975885e9118e87cc51e929d254': <tethne.classes.paper.Paper at 0x10d88c350>,
#  'ea3cde9bf9b9d068d6e8196f32b61142': <tethne.classes.paper.Paper at 0x10dd6ffd0>,
#  '026578239353679458325c9d59ca940d': <tethne.classes.paper.Paper at 0x10da60590>,
#  '7000ea5257ac74c96c7aae0c60c0aa5f': <tethne.classes.paper.Paper at 0x10dd4c110>,
#  '4bff17a68a71d35733cb77a1fffbbebd': <tethne.classes.paper.Paper at 0x10f64cc10>,
#  'dd432214e3e4039f34655fbb0d924ebc': <tethne.classes.paper.Paper at 0x109d50690>,
#  '46ed1496088ae8d8fe153ca8a2166f0d': <tethne.classes.paper.Paper at 0x11e84ac10>,
#  '73dff7d3c0cabef39202df5fa1d8f493': <tethne.classes.paper.Paper at 0x10d9d6050>,
#  '71e56dc49ebfc21d6f5473c1dc4044ae': <tethne.classes.paper.Paper at 0x11564c710>,
#  '68c1ddf38f5f214926ad1317ca78dc3b': <tethne.classes.paper.Paper at 0x1215e0450>,
#  'eafe6b75b33e49d93e27823e4b02dfc2': <tethne.classes.paper.Paper at 0x11fea1f90>,
#  'e268c21bb9b1d81476a3a2b7a185a14d': <tethne.classes.paper.Paper at 0x110397dd0>,
#  'd37bba9a9d4a60319a1c985a52268dc0': <tethne.classes.paper.Paper at 0x11d274850>,
#  'dfab96ee84d27faae0e1889b18783ccb': <tethne.classes.paper.Paper at 0x10d7c9f90>,
#  '4e11f67f3f1a0672f11a0a89560357cc': <tethne.classes.paper.Paper at 0x11b231310>,
#  '1e5e375423d89af425220df07f226859': <tethne.classes.paper.Paper at 0x10d7b2050>,
#  'f70bc2b124a65252f768a859018d36a8': <tethne.classes.paper.Paper at 0x10db85850>,
#  '0b104adc1b0a9f1d97572ff8af4c3d62': <tethne.classes.paper.Paper at 0x11b231650>,
#  'bd78b008b9245eb334bede1aee3e3818': <tethne.classes.paper.Paper at 0x10f64ca50>,
#  '53f87adab80510d02b07d07a03a045c7': <tethne.classes.paper.Paper at 0x10db90150>,
#  '814722b7fa9cedd2c046310fe82bcd32': <tethne.classes.paper.Paper at 0x10d88c310>,
#  '3f1e8e2591372f7f3bfc85f3efa5171b': <tethne.classes.paper.Paper at 0x10da60150>,
#  'e845ee4a13eab577545a023f2244fe10': <tethne.classes.paper.Paper at 0x10db9c390>,
#  'b20808290a8e032a3b2b87a5be232430': <tethne.classes.paper.Paper at 0x106ab93d0>,
#  'bb6bd2f0dd1b75cdf4fffb06d090db3f': <tethne.classes.paper.Paper at 0x10f64ca90>,
#  'a27b906fc01e6461efe841db1106a3a3': <tethne.classes.paper.Paper at 0x110397290>,
#  '01e838d2d062a4b23c7c95787d8cc92c': <tethne.classes.paper.Paper at 0x11d0a6250>,
#  'f144d7461e5e0bed7a8dc371908e60cd': <tethne.classes.paper.Paper at 0x10deda150>,
#  '4132ec7661981b9847fb4753dd8b28a1': <tethne.classes.paper.Paper at 0x120002a90>,
#  '5fa8e475b6b72a08ec0e7c4dfa03d8ef': <tethne.classes.paper.Paper at 0x10d7d3190>,
#  '85d4b6acd37601ceb9c2c84af6626cdf': <tethne.classes.paper.Paper at 0x1215e0ed0>,
#  '553996d16ed84f850ecb07064428b11c': <tethne.classes.paper.Paper at 0x10da03250>,
#  '63e7f4866ef5c3409c5c4a873c72cde2': <tethne.classes.paper.Paper at 0x10d7d3d90>,
#  'ade5486d3ff22e75b8f781dc004b4d6d': <tethne.classes.paper.Paper at 0x10f64c9d0>,
#  '8a1ad9c09ac52712095d6fb6402e123c': <tethne.classes.paper.Paper at 0x120002910>,
#  'fef52b0157a8106f4a0269fb2c074cac': <tethne.classes.paper.Paper at 0x1085b8a90>,
#  'd5c73c9d1f69b116450881934d6648f5': <tethne.classes.paper.Paper at 0x106a532d0>,
#  '0ef6bb66d0b882b201c5c8773279e05e': <tethne.classes.paper.Paper at 0x10deb45d0>,
#  'ff32a892f0752c34c9908374fd231864': <tethne.classes.paper.Paper at 0x11d0a6550>,
#  '7c10c9de01ba5eb482ba039a6d81f186': <tethne.classes.paper.Paper at 0x10da78150>,
#  '04ea2c77901bb8dc696dbe9c7eaf3cd6': <tethne.classes.paper.Paper at 0x10d79bb90>,
#  '874e877c1a93f759210225b8fcf08275': <tethne.classes.paper.Paper at 0x10d79bfd0>,
#  '7f1ec39336508c6da944c64b39f094a3': <tethne.classes.paper.Paper at 0x11b231c50>,
#  '479bd61cf4e8e1bcfd474d6d0f017c9e': <tethne.classes.paper.Paper at 0x10da60810>,
#  '66c2c7ad1917fa35b51e2f6b9b0bbb77': <tethne.classes.paper.Paper at 0x10d8258d0>,
#  'c88bba7199a1bb3e27d2c72ed5691a0e': <tethne.classes.paper.Paper at 0x10dea9110>,
#  'ba9f80b9d735c99abd732a4eb4fbbbbf': <tethne.classes.paper.Paper at 0x10deb4f10>,
#  '0dab0929ce7023aa7a072104314116a8': <tethne.classes.paper.Paper at 0x11564cfd0>,
#  '12bed0545d0b0398f6d8fc19fe513210': <tethne.classes.paper.Paper at 0x107a32cd0>,
#  'e0cb3358c650bdd5d4b324d82b1f40ef': <tethne.classes.paper.Paper at 0x10dd7a1d0>,
#  '3998b890aba9f81215c05737aa80d439': <tethne.classes.paper.Paper at 0x10d778ad0>,
#  '50274ba95695702d030687963afb60dc': <tethne.classes.paper.Paper at 0x10d727190>,
#  'ef852e42385c4c1f57f68fd2b29bafd3': <tethne.classes.paper.Paper at 0x10d803050>,
#  '6629a16e6db44dcb52c37b2b75a84f66': <tethne.classes.paper.Paper at 0x1215e0190>,
#  '580bc3af07a13ac6c34e8a410583b9f8': <tethne.classes.paper.Paper at 0x10daeb290>,
#  'e4203eae8826c38e3fd1fd17462b3fd5': <tethne.classes.paper.Paper at 0x10dd6f490>,
#  '1ffb1464f7f0beaa712ea0d6af32b915': <tethne.classes.paper.Paper at 0x10d8b1210>,
#  'b702cd91689f76cd05b81cc7449fe9ec': <tethne.classes.paper.Paper at 0x10da03ed0>,
#  'ef88ef1789e9f48574fdab884b82d3c8': <tethne.classes.paper.Paper at 0x10df36990>,
#  'bb936c97f3984a19e2ee49e738cdf16a': <tethne.classes.paper.Paper at 0x10de9d250>,
#  '982aeb3e2d165bb1fad1d0ac2e132305': <tethne.classes.paper.Paper at 0x10dca8790>,
#  'b69c949aec42abe33c1444f9344f0b85': <tethne.classes.paper.Paper at 0x120002950>,
#  '73831fc707f32fe81096f85d962128a9': <tethne.classes.paper.Paper at 0x10f64c710>,
#  '58861616ca3cff92757a5ef2b47ba9b6': <tethne.classes.paper.Paper at 0x11d0a6210>,
#  'f0c52f970f4a453cba7d9b4f9da0644d': <tethne.classes.paper.Paper at 0x10d825c90>,
#  '5ffa6bf9c11fe7b0f79f61ac58e7d718': <tethne.classes.paper.Paper at 0x10db85d50>,
#  '1850a22f2ab6273e6bcc47d1e54df12c': <tethne.classes.paper.Paper at 0x10d86b4d0>,
#  'b801eeb15706d388f99f2dd89b8f06a7': <tethne.classes.paper.Paper at 0x120002f10>,
#  '62e7d7424b2df2b09f86b276cd8bc29a': <tethne.classes.paper.Paper at 0x10f64c910>,
#  '4a9e0601363af5ad298c719339f6fa35': <tethne.classes.paper.Paper at 0x11d2746d0>,
#  'fc46690e0d4e0e981dd90b9ffced5629': <tethne.classes.paper.Paper at 0x10d881b90>,
#  '4a45fe1a3f2682e34bf1b2bf3c8ef399': <tethne.classes.paper.Paper at 0x11e84a410>,
#  'd0600fd68a238b568a65fb8ad2764bf8': <tethne.classes.paper.Paper at 0x11564c5d0>,
#  '5c1fe337a43c59b889a646c2dce6916d': <tethne.classes.paper.Paper at 0x10da03210>,
#  'ba1715c442dc1a49466f06a762a22e7b': <tethne.classes.paper.Paper at 0x10db58590>,
#  'c0f84527ba9d0b0c61890b7d1c3c473b': <tethne.classes.paper.Paper at 0x1172e4750>,
#  'e91b732d5df24d4ce61ccb62c92b1345': <tethne.classes.paper.Paper at 0x10d8c82d0>,
#  'd35e77ff1b0e3973251fea10afa8a74f': <tethne.classes.paper.Paper at 0x10d79bb50>,
#  'f09f5a58851cd8ceafc125a73ae0e93b': <tethne.classes.paper.Paper at 0x10a4863d0>,
#  '23ea8001a3e0fe19ed5597bdb12d869e': <tethne.classes.paper.Paper at 0x10f64c290>,
#  '0cba4e892a9fa48ea60ad1df74eb113a': <tethne.classes.paper.Paper at 0x10dbcbbd0>,
#  '09ecccb7bf77dda21f68e3da9cf0df17': <tethne.classes.paper.Paper at 0x11fea1090>,
#  '92731d897329eee7642806c240f9d6e7': <tethne.classes.paper.Paper at 0x11e84a610>,
#  'bbdb860af302089d126d10fa3f1e5626': <tethne.classes.paper.Paper at 0x10d7be1d0>,
#  '0deaf678f71ba3d639a71ac1d727dfb4': <tethne.classes.paper.Paper at 0x1172e4b50>,
#  'e016017c4a79d2db239c27f7ccf09bcb': <tethne.classes.paper.Paper at 0x110397510>,
#  '6940731359b0a46d324cd937d4330379': <tethne.classes.paper.Paper at 0x10bd00810>,
#  'acaf77a4157ecf9d5212fe548741f1de': <tethne.classes.paper.Paper at 0x10db85b10>,
#  '1b93d09d058d1503786c05f9d90a772c': <tethne.classes.paper.Paper at 0x10dc86090>,
#  'dc9970fca5060b438b5fc06ca742fa6c': <tethne.classes.paper.Paper at 0x11fea10d0>,
#  '02c820ab61c37d147cf1f207d1bdeb52': <tethne.classes.paper.Paper at 0x10ba23350>,
#  'b1596ddaec816ee796233d25a695f67b': <tethne.classes.paper.Paper at 0x10de570d0>,
#  '91bd61af8b42c34508a818d5408ae63f': <tethne.classes.paper.Paper at 0x106a53250>,
#  'ef5bfc1a323f9c30565c6bea2dfd6d97': <tethne.classes.paper.Paper at 0x11d0a61d0>,
#  '8c1fd950901c9d8b58e28a3f3319ebd7': <tethne.classes.paper.Paper at 0x10da60510>,
#  'a60f4ea30d7bd6d1abbc0a8701ffa871': <tethne.classes.paper.Paper at 0x10f64cb50>,
#  'ff0fde4f3c7b5815d71a0dfc355efcad': <tethne.classes.paper.Paper at 0x1074c0f90>,
#  '9b87976effc72efeeea4b4909c0f37b5': <tethne.classes.paper.Paper at 0x11d0a60d0>,
#  '6d1f656ec181beb8766891a9bdf7b404': <tethne.classes.paper.Paper at 0x10deb4790>,
#  'e2b40a121abfb3a2e0dc8ca6a7ead70e': <tethne.classes.paper.Paper at 0x10da03090>,
#  '82f1f484e51cb6a079a018ea6036b06c': <tethne.classes.paper.Paper at 0x10db6e2d0>,
#  '426c7be2f08af42064bd0cb4eb44e00f': <tethne.classes.paper.Paper at 0x10deb4490>,
#  'c439ecacfb84b01f529d6df085491ad1': <tethne.classes.paper.Paper at 0x10deb4610>,
#  '1eb580e862b79691b1b2c7b06a259b8a': <tethne.classes.paper.Paper at 0x10f64ce90>,
#  '4ac7d11a275304dac87fd600920cb8a1': <tethne.classes.paper.Paper at 0x120002190>,
#  '93f5d2371f5bcc0bb8c174c6ac5679e7': <tethne.classes.paper.Paper at 0x1172e4490>,
#  '3ff718186575082b324cc7498bf9f016': <tethne.classes.paper.Paper at 0x11b231b10>,
#  '30ecf5a84ad244d9ea925dcce13320e6': <tethne.classes.paper.Paper at 0x106a80250>,
#  '50741f814d982193c436700c9a5178a7': <tethne.classes.paper.Paper at 0x110397d50>,
#  'd7cf5284225bfe5bfe446d000ad84247': <tethne.classes.paper.Paper at 0x1172e4250>,
#  'b3dd94e4d2787f3301d22fba59e39910': <tethne.classes.paper.Paper at 0x11564ccd0>,
#  '734309d639feb5a2c4e12e5191df8f47': <tethne.classes.paper.Paper at 0x10dd56590>,
#  '33d8853c80033a775ad99821e1be2d32': <tethne.classes.paper.Paper at 0x10dbee250>,
#  'a36f89f7b89b383bc357adda4faddb0d': <tethne.classes.paper.Paper at 0x11d0a6e50>,
#  '1628c70cbadea3e908409137891c72b0': <tethne.classes.paper.Paper at 0x1103973d0>,
#  'e1e1fd87ce906fe39db336157044bc6e': <tethne.classes.paper.Paper at 0x10dd6f110>,
#  '43f681bbdb4e7373962183428cc57277': <tethne.classes.paper.Paper at 0x10d7c98d0>,
#  '7f800c725721337eef0aafcacd0bef22': <tethne.classes.paper.Paper at 0x120002b50>,
#  '0eef3e69589f27fb1cbb9c2cc6ed3f00': <tethne.classes.paper.Paper at 0x1215e0310>,
#  '0e061e7e6fc4e77dcdcb1be98d1d9269': <tethne.classes.paper.Paper at 0x10dcd7590>,
#  '200bc1351bf08eb0b7b8797c1d4bd98e': <tethne.classes.paper.Paper at 0x10d98f9d0>,
#  'b143f19020c1f5ad606578582d56fca6': <tethne.classes.paper.Paper at 0x110397a90>,
#  '77f08351c6d54a594124dd89b12c8ab4': <tethne.classes.paper.Paper at 0x11d274a10>,
#  '749989bf82c7c76b57c8c4a222d091d2': <tethne.classes.paper.Paper at 0x10d7c9890>,
#  '52e27a83d679459cec532f5be4faf3b0': <tethne.classes.paper.Paper at 0x109b871d0>,
#  'c88f88ac0fb6289276531347c8637869': <tethne.classes.paper.Paper at 0x10723d250>,
#  'a74baa04fd7262213ed1cc4114c71db9': <tethne.classes.paper.Paper at 0x10d7c9cd0>,
#  '525c87ef12837ae328fb0c636bd6ac45': <tethne.classes.paper.Paper at 0x110397bd0>,
#  '4aa1e4bfd4ca1556ae396a53193d1191': <tethne.classes.paper.Paper at 0x10bcde210>,
#  '52b2e81375a28f103ede97d14e6a7151': <tethne.classes.paper.Paper at 0x10a92cc50>,
#  '59aa147e2f8f6527de2b30f44aa0427d': <tethne.classes.paper.Paper at 0x10746c090>,
#  '553554433809e94ec2e9f8195aa220d4': <tethne.classes.paper.Paper at 0x10db15710>,
#  '52be3609bb5e60cf13f6534dd54f6dfd': <tethne.classes.paper.Paper at 0x11b231150>,
#  'fe6e2a735758415a5449f821d3b07ef4': <tethne.classes.paper.Paper at 0x1200029d0>,
#  'e692896ca59d534f7c9cc283bd13d88b': <tethne.classes.paper.Paper at 0x11fea1190>,
#  '6396c10f6f243f1fdbe75f7947ecd15d': <tethne.classes.paper.Paper at 0x10969a250>,
#  '3d135cec0fd640a30d91344492088c23': <tethne.classes.paper.Paper at 0x10b8b7090>,
#  '586ed356f23e6d8ab6d72648f512d9d8': <tethne.classes.paper.Paper at 0x11629b2d0>,
#  '274cb7adb19e3440559508d89a628a58': <tethne.classes.paper.Paper at 0x10d79b810>,
#  '14c58cc0d043cf9339de754b45fa71bc': <tethne.classes.paper.Paper at 0x11e84abd0>,
#  '177ce6dad2c5a8eebfd2bc9d13983fa9': <tethne.classes.paper.Paper at 0x10f64c150>,
#  'e409e03cb06a8e8e7afbff98f289779d': <tethne.classes.paper.Paper at 0x10d9b3190>,
#  '543e58ccb6db92717efee7d2ec1b2d3c': <tethne.classes.paper.Paper at 0x11564c390>,
#  '70796a576851f7c0da6a73885609cad2': <tethne.classes.paper.Paper at 0x1172e4c10>,
#  '23a4b11b5a63f7c928c34889f5b0826b': <tethne.classes.paper.Paper at 0x10f411990>,
#  'e8ad6c24e66e40a687b846e4d2317f2c': <tethne.classes.paper.Paper at 0x1215e00d0>,
#  '883138949600901adccd2068a76cb646': <tethne.classes.paper.Paper at 0x10d7c9110>,
#  'fb5de5e6dbc8f520cc5270a246b5da36': <tethne.classes.paper.Paper at 0x10bf891d0>,
#  '5bcb509473624091ddde07c0d101ef04': <tethne.classes.paper.Paper at 0x10bfb8110>,
#  'b8f23f982cc5252d3651b7d7bdd6134b': <tethne.classes.paper.Paper at 0x10d7c9e50>,
#  'f10ca5e29708d5d2e93a511d5b4d39e2': <tethne.classes.paper.Paper at 0x109673190>,
#  'f5079708692a87cc31daeaf0e6b7129f': <tethne.classes.paper.Paper at 0x10f64c4d0>,
#  '1044a51d863110035d25ab2248c85d86': <tethne.classes.paper.Paper at 0x10db40250>,
#  '63a6ea6ab009cf7408ddd19da76e6ba3': <tethne.classes.paper.Paper at 0x10bfce090>,
#  'b5baf9d490994185c407583417feb70f': <tethne.classes.paper.Paper at 0x10a1658d0>,
#  '4c77ceb7f5a2f24eea26c20a52aeaa6a': <tethne.classes.paper.Paper at 0x10d860190>,
#  'c936a382ab6ca3f7d6545a096c8eff52': <tethne.classes.paper.Paper at 0x10db85490>,
#  '67fffc18b158534469f2d4500f041640': <tethne.classes.paper.Paper at 0x1095dfa90>,
#  '4d0d18b6bbc885573b81481d0af6b37f': <tethne.classes.paper.Paper at 0x10f64c850>,
#  'a778c483bceaca15f52d67f9503a8480': <tethne.classes.paper.Paper at 0x10dced050>,
#  '9fe6f88a8ae5bea2172c6a05aae7168a': <tethne.classes.paper.Paper at 0x10defb090>,
#  '87b9cf37530f593deeb89af4f7517266': <tethne.classes.paper.Paper at 0x10dceded0>,
#  '8a3f78e0d550d2f51e00f54d9578c4ec': <tethne.classes.paper.Paper at 0x10dced810>,
#  '66267214806b582e1c0d7dee95863152': <tethne.classes.paper.Paper at 0x10d79b850>,
#  '136a9f0753cd88f3cd556466de7a4303': <tethne.classes.paper.Paper at 0x1172e4a10>,
#  'aba473a9d1a701cac7c391c067394f97': <tethne.classes.paper.Paper at 0x10bd0c2d0>,
#  'f3b4b5811b7ef9cc725489ddd3c6ba14': <tethne.classes.paper.Paper at 0x11fea1290>,
#  '92304e3b0755facba463453278cce8e0': <tethne.classes.paper.Paper at 0x10df41110>,
#  '107ad03da2f7bd18752676eb8d99ad37': <tethne.classes.paper.Paper at 0x11b231590>,
#  '0a69f91b58575f61d0f4590c5c662da4': <tethne.classes.paper.Paper at 0x10da91290>,
#  '217023e313ccefc823320f6ccbc50f13': <tethne.classes.paper.Paper at 0x110397250>,
#  '246d13f06a12e142336b76b2ceb4d40a': <tethne.classes.paper.Paper at 0x10db85690>,
#  '178b5d319be3a0a0a5fa7c6ba20f1f81': <tethne.classes.paper.Paper at 0x10f64c1d0>,
#  'a46000d24c31f3194ec4972c7d479b00': <tethne.classes.paper.Paper at 0x11d0a6150>,
#  'cdff23d2b889df93b1759f76791d1070': <tethne.classes.paper.Paper at 0x10bf70110>,
#  '9050eafc78e017b494246c666160dad1': <tethne.classes.paper.Paper at 0x11e84afd0>,
#  'd264501e111f26bcdbdd204aaf80244e': <tethne.classes.paper.Paper at 0x10bf89510>,
#  '8fdd7b0a0b975cb10cc6f8960fe260a6': <tethne.classes.paper.Paper at 0x10a410a90>,
#  '319614a33c6c60099b1bce8ed20273c0': <tethne.classes.paper.Paper at 0x10bd0c210>,
#  '82f32b10d65343e326b921cde982d7a9': <tethne.classes.paper.Paper at 0x10d8eb190>,
#  '926c0231ec8b1e218416e52259d10903': <tethne.classes.paper.Paper at 0x11b231850>,
#  'a5c86b737b37911609a78ea9e9747fce': <tethne.classes.paper.Paper at 0x10dec3f50>,
#  'b89e9f4c70ec00adc54ccd55c6e5f18f': <tethne.classes.paper.Paper at 0x10afb4d50>,
#  '47405483864e410967e16756b77dd10d': <tethne.classes.paper.Paper at 0x1215e0e90>,
#  'cc656d330832123f992e3357eb3234a3': <tethne.classes.paper.Paper at 0x11fea1350>,
#  'be786f0c93f009e5049c14b0d6cfc772': <tethne.classes.paper.Paper at 0x10d7d3d50>,
#  'bbc1ca2b53b78328d504bc6f713a36c8': <tethne.classes.paper.Paper at 0x10d854490>,
#  '6ee5e18f150a517c898e0a363538ac31': <tethne.classes.paper.Paper at 0x10daa8210>,
#  'df77ea63d085ee6262997479ba673820': <tethne.classes.paper.Paper at 0x110397210>,
#  '5f4d46f10813fc4bfb279d466ac366df': <tethne.classes.paper.Paper at 0x10dc06250>,
#  '17c0b3b9052a4881b1fb16f9123a4406': <tethne.classes.paper.Paper at 0x1116f48d0>,
#  '04ce7e4ba7becf629b05da48e703ad3f': <tethne.classes.paper.Paper at 0x10dd6f190>,
#  'd628ba62b0a7bad1114a7789d9139293': <tethne.classes.paper.Paper at 0x10dced6d0>,
#  '27143872e4f8704d0e835d5555d2ede6': <tethne.classes.paper.Paper at 0x10d803150>,
#  '1df5f403f9fd160c94a01611ac1185a7': <tethne.classes.paper.Paper at 0x10a77ce50>,
#  '4bc186acf2b1e268c4fbc32d605be3d8': <tethne.classes.paper.Paper at 0x10d7d3f90>,
#  'c2d3b4eb357d6c0772fc9c2e713a226a': <tethne.classes.paper.Paper at 0x10d79bd10>,
#  '1623ac92abc8e027c7e44486402e48e3': <tethne.classes.paper.Paper at 0x10bc313d0>,
#  '34d271819c955a275a537a2a480593cc': <tethne.classes.paper.Paper at 0x10d783750>,
#  '243777372794e108b58c28167bf8076a': <tethne.classes.paper.Paper at 0x10dcede50>,
#  'dd045684224db0ef398575e37ab58847': <tethne.classes.paper.Paper at 0x10dd6f990>,
#  'b80452a0d079034033e63952a6bcf805': <tethne.classes.paper.Paper at 0x10bc1c410>,
#  'afff7130adf31482d550513c6ed8f0f3': <tethne.classes.paper.Paper at 0x10da03f90>,
#  'eebd1aefe8fb7e4d27bb92181f254b61': <tethne.classes.paper.Paper at 0x10f2f7dd0>,
#  '546d7cfdc85fd885eb8de40468119d74': <tethne.classes.paper.Paper at 0x10d7c9910>,
#  'daaa0d362633abea3e7fe9d5e2817f2e': <tethne.classes.paper.Paper at 0x10ddb5710>,
#  '336d2fc45b027623ec0a2bd3df28e408': <tethne.classes.paper.Paper at 0x10ba23390>,
#  '0938bec9b85747c51f74a7d2ce6881b3': <tethne.classes.paper.Paper at 0x1172e4a50>,
#  '4ad046d196eed07376501b8b7ad5d342': <tethne.classes.paper.Paper at 0x10d825850>,
#  '65e39868aec0d787d8b38d2708d07cad': <tethne.classes.paper.Paper at 0x10dcedf10>,
#  'febb9113b054784d701084da0496386b': <tethne.classes.paper.Paper at 0x10deb4750>,
#  '4be1ce2763fc39337a14c0c0bf581976': <tethne.classes.paper.Paper at 0x1215e0c50>,
#  '0e77e40cc500c5508239605ac384045a': <tethne.classes.paper.Paper at 0x10da60250>,
#  'dab159103f97842ec8dd3f3a15a40265': <tethne.classes.paper.Paper at 0x10dbee650>,
#  '24812316acc996a34ef10c00d808a98e': <tethne.classes.paper.Paper at 0x11e84aa50>,
#  '3bd1f0ac5e073fdfa365621c61d4f9f5': <tethne.classes.paper.Paper at 0x116f5a2d0>,
#  '4d25f00997a26b4c774d9b201165724e': <tethne.classes.paper.Paper at 0x11b231f50>,
#  'a671f839f26fabdb6d5bf3d636d5d5ef': <tethne.classes.paper.Paper at 0x10de1e110>,
#  'a62faf491190f90c40acd2145934b5d6': <tethne.classes.paper.Paper at 0x10d79b0d0>,
#  '3c22773b3e6ec93a4d4c9e325fbf4451': <tethne.classes.paper.Paper at 0x1215e0210>,
#  '1c898d3bbbaaa0c3b477ac9e18b8a9be': <tethne.classes.paper.Paper at 0x10d96d0d0>,
#  '2e5e8ec5940185239f45adf5f8578aa7': <tethne.classes.paper.Paper at 0x11d0a6410>,
#  '7ffc793d57f38ffbc58f77e3ceb1967a': <tethne.classes.paper.Paper at 0x10d7d3710>,
#  '2eb252a9ef46fdc07d687e6a169e9986': <tethne.classes.paper.Paper at 0x10dd6f6d0>,
#  '747bfcbc0a48fa15f703cf3c49a6e2c5': <tethne.classes.paper.Paper at 0x1215e0f90>,
#  '370ae24c5a02ad9e49e574e0a51de203': <tethne.classes.paper.Paper at 0x11d2744d0>,
#  'b51fe143b38a91074ebbf1d494a5d0d4': <tethne.classes.paper.Paper at 0x11b231410>,
#  '1d87e873aedcae7c929a883f0e42e432': <tethne.classes.paper.Paper at 0x11e84a5d0>,
#  'c64797cfe66bb88ae4c902918db73393': <tethne.classes.paper.Paper at 0x11d274790>,
#  '32424ce40c356261c949d12f5ab281ec': <tethne.classes.paper.Paper at 0x10da03810>,
#  '6f02016943b3f8052d82fa192a176c99': <tethne.classes.paper.Paper at 0x10bf36350>,
#  'be6adcacc16c7b767c6cc785856d5547': <tethne.classes.paper.Paper at 0x107299f50>,
#  '8f9bae4b00cee7308ec13fefcde724a4': <tethne.classes.paper.Paper at 0x10de3f090>,
#  'e3d3353986057cf40269bd67ad014854': <tethne.classes.paper.Paper at 0x108fdca90>,
#  '723415bb56ba2e28ee88813e780f3cf4': <tethne.classes.paper.Paper at 0x10dc7a590>,
#  '22273b5d6ad139d6e4e7f774547c061a': <tethne.classes.paper.Paper at 0x110397fd0>,
#  '48111101d8c5f486600f4cd6a1d84b28': <tethne.classes.paper.Paper at 0x10d8b11d0>,
#  '1734dacc844667b475d245b6800d1fee': <tethne.classes.paper.Paper at 0x10deb4b50>,
#  '48f55e3d438e6fa79e2b36f730c86356': <tethne.classes.paper.Paper at 0x10d79b350>,
#  '8e3f888a26e149048c677d5edfbf0798': <tethne.classes.paper.Paper at 0x11fea1d90>,
#  'ebe1fb0912ce45862217f1aad47f2409': <tethne.classes.paper.Paper at 0x10deb47d0>,
#  '00c3346fe3582e41e6f3e22307517df1': <tethne.classes.paper.Paper at 0x10d8254d0>,
#  '70cc720bc265ffb8af5e17859b89b028': <tethne.classes.paper.Paper at 0x10d904650>,
#  'b5c326f1cfaab81b6263dcd0dbc86d2f': <tethne.classes.paper.Paper at 0x10da3e450>,
#  '22a4545034a98cc785d038ed52336851': <tethne.classes.paper.Paper at 0x10d79b450>,
#  '819f454f3ecb9d1d2a110b4fdb36c1f7': <tethne.classes.paper.Paper at 0x10d7c95d0>,
#  '0bdf838d599cdcebb2f5b51973d7b3df': <tethne.classes.paper.Paper at 0x1215e0890>,
#  'e267eacdf2d6520bab759c1d8ee5f56b': <tethne.classes.paper.Paper at 0x108d30d50>,
#  'ebb67654fbc54f573327a963a42e2590': <tethne.classes.paper.Paper at 0x10dbc10d0>,
#  '481db0904eedc1ec9d093c43cd7c094d': <tethne.classes.paper.Paper at 0x10d9d6390>,
#  '8fe0427deeb1a0d6da71f2cfcee2ca3f': <tethne.classes.paper.Paper at 0x109602a10>,
#  '4572e01718004e636d5d2f30e0370ed1': <tethne.classes.paper.Paper at 0x10d7d3310>,
#  '00fe74254b9f1f8c2408b78a711d8f54': <tethne.classes.paper.Paper at 0x10b02a690>,
#  '7ca8da0646e12ec388c7db569c83e808': <tethne.classes.paper.Paper at 0x109bfb110>,
#  '6e08fe1d769da6899a932f3241ec7d03': <tethne.classes.paper.Paper at 0x10854d310>,
#  '8f128085856c531b9966c8a57c9287ac': <tethne.classes.paper.Paper at 0x10d79b790>,
#  '5d7edf8d8eea4e1890bcb49742fabbbb': <tethne.classes.paper.Paper at 0x10d79b650>,
#  '6485ffe0bd2addb548f3db3956db6b1b': <tethne.classes.paper.Paper at 0x10f64cf90>,
#  '6c9446d8b060936227791689823fe28e': <tethne.classes.paper.Paper at 0x10ba46190>,
#  '50ca82069ee2cd311896c386be6981dd': <tethne.classes.paper.Paper at 0x11564c6d0>,
#  '469e8d027eaed928527d2dbb6f65567a': <tethne.classes.paper.Paper at 0x1215e0690>,
#  '950fcdc43671103ceace03eb48ed3c1e': <tethne.classes.paper.Paper at 0x10dcb3210>,
#  '8295ed9e2c9fe918a132bcbd4ae295ed': <tethne.classes.paper.Paper at 0x10d825910>,
#  'cf3e43325df21f778b4cf4674124ba13': <tethne.classes.paper.Paper at 0x10d79b050>,
#  'a58b286d36f7ce6fe1586aa54212bbc2': <tethne.classes.paper.Paper at 0x1079b3510>,
#  '5bd2911db750baeea7faf768e1f48d75': <tethne.classes.paper.Paper at 0x10db85450>,
#  '56d91f2292b72c28d80ddead8a30b815': <tethne.classes.paper.Paper at 0x10dd6f690>,
#  '37dfa23b7375ff4f06980f673d7afaba': <tethne.classes.paper.Paper at 0x106ab9390>,
#  '40c1881edc7f482a397f06996c9f52d6': <tethne.classes.paper.Paper at 0x11564cb50>,
#  'b09d968000b22373c12735c63fa6f339': <tethne.classes.paper.Paper at 0x10da03cd0>,
#  '2d951132a0cfda71046450f84f3f13f4': <tethne.classes.paper.Paper at 0x10db2a110>,
#  '3cf5f71149e1068f8473b4279d404853': <tethne.classes.paper.Paper at 0x110397cd0>,
#  '240cc2665846de80a018b9021646328d': <tethne.classes.paper.Paper at 0x10deb4d50>,
#  '93537e6649224b3f72f8eff963062c26': <tethne.classes.paper.Paper at 0x10dd9da10>,
#  'c65d80663cfbcac0165f7c38317f8424': <tethne.classes.paper.Paper at 0x10bceaf10>,
#  '1e734d32416503820dc74d26a030ee30': <tethne.classes.paper.Paper at 0x110397e90>,
#  'fb9051c807368cf603aad5542899d762': <tethne.classes.paper.Paper at 0x1081d7b90>,
#  '0caa2fa453daaa1a3a5c78c095216e5f': <tethne.classes.paper.Paper at 0x10dd11050>,
#  '4bf0163cbdc83f78d694475f33db9274': <tethne.classes.paper.Paper at 0x10dd6fc90>,
#  '8990ebd939c4340910fa130d8e7195c3': <tethne.classes.paper.Paper at 0x1103976d0>,
#  '163d024537826e86a84c8450775dfe53': <tethne.classes.paper.Paper at 0x120002690>,
#  '43a909345dc6c425e9864e6f52552b97': <tethne.classes.paper.Paper at 0x10d79b090>,
#  '0d83d9b650f49bf55c0230dfcf955fac': <tethne.classes.paper.Paper at 0x10dc061d0>,
#  '6e5f3e628fa955cf32970a840b38b584': <tethne.classes.paper.Paper at 0x109c78b50>,
#  '09b9f3e85ae91717f815f09831a9ba26': <tethne.classes.paper.Paper at 0x10d98f290>,
#  '473b0372a57848a8f9f044508b584c1a': <tethne.classes.paper.Paper at 0x106b7f0d0>,
#  'd41d8cd98f00b204e9800998ecf8427e': <tethne.classes.paper.Paper at 0x10d81a110>,
#  '14fc419328e56b3a783a94f97d4fccf2': <tethne.classes.paper.Paper at 0x10d8bc090>,
#  'b4140912cc5d69583684ef0f7182d1e4': <tethne.classes.paper.Paper at 0x1093369d0>,
#  'd715942d88f811a282884ce39a71b91c': <tethne.classes.paper.Paper at 0x10deb4f50>,
#  '0f79083332bf449da8dcf1188983c032': <tethne.classes.paper.Paper at 0x10da60f10>,
#  '250bc4a6197d8a202310463262d5982d': <tethne.classes.paper.Paper at 0x11b231090>,
#  '6f63bd996bf1bdfebecc39edfb98b3f2': <tethne.classes.paper.Paper at 0x10db85e90>,
#  'debd19df50e5f72405423d9598525073': <tethne.classes.paper.Paper at 0x10dd6f5d0>,
#  '6deb74b6406aef3206cc93c72e63be01': <tethne.classes.paper.Paper at 0x11e84acd0>,
#  '5f27d40a0111b2d009b7a5f1902571a1': <tethne.classes.paper.Paper at 0x11b231890>,
#  '45938773812b10099778ffed167cc62b': <tethne.classes.paper.Paper at 0x10dced510>,
#  'f8b4a703c09237ebafb820019b7dc52d': <tethne.classes.paper.Paper at 0x10dece290>,
#  '5879633a4881173af199733c6e052d11': <tethne.classes.paper.Paper at 0x11564c690>,
#  '4ba5feb7b5992ad4cfec44b6b5c679ed': <tethne.classes.paper.Paper at 0x10da03e10>,
#  'c71204ffbd37d358714377f92186297a': <tethne.classes.paper.Paper at 0x10d7d34d0>,
#  'd0b08efabde28ca8ad889b0eaf535428': <tethne.classes.paper.Paper at 0x10d79bc50>,
#  '0bec116555d8c12d66175ceaffd06052': <tethne.classes.paper.Paper at 0x1215e0ad0>,
#  'f1b546943ce6126a5c06445bcdbdc7f7': <tethne.classes.paper.Paper at 0x1215e0550>,
#  '6a8c0f072f5e41a27e93338cd3bfc909': <tethne.classes.paper.Paper at 0x10d79b490>,
#  '41b6bc7debf043a832ace951c3bb4361': <tethne.classes.paper.Paper at 0x10bc1c090>,
#  '94222f00df8bd0c6ea25a777b8f704c2': <tethne.classes.paper.Paper at 0x11564c310>,
#  'e47cbff5a1971fdb626b2d650d9419ce': <tethne.classes.paper.Paper at 0x10aa58d10>,
#  '66f7b0f6598fd365418d853003c432c6': <tethne.classes.paper.Paper at 0x11d274750>,
#  'ba95f09aa16f7e8f188cc16db4e92350': <tethne.classes.paper.Paper at 0x10d7c9750>,
#  '493b926bf0d857635e6c74c5ee995b96': <tethne.classes.paper.Paper at 0x10da60790>,
#  '17391375b17cb28d51bc65eacb4c3147': <tethne.classes.paper.Paper at 0x10d7d3510>,
#  'a929c59662d0cbd4d48f9f7d279efcba': <tethne.classes.paper.Paper at 0x10dced090>,
#  'd017b62a77f85fa32304b463794d3322': <tethne.classes.paper.Paper at 0x1172e4650>,
#  '1fed7aae03d2ab312ab1f90ca4e40bd3': <tethne.classes.paper.Paper at 0x10deb4c50>,
#  'fcad110ced5a5784fd31c8c3b757d566': <tethne.classes.paper.Paper at 0x11b231bd0>,
#  '92337b56bf0986d2fa0e0faeb129e7e0': <tethne.classes.paper.Paper at 0x109d2a490>,
#  '104ce1a7fa6453ae600d43a5a79ec213': <tethne.classes.paper.Paper at 0x10da3e490>,
#  '506f1dee4fe8bbfc7b2fbd1f611c5e9b': <tethne.classes.paper.Paper at 0x1121b8e90>,
#  'd1c6595fbe20e3144cd140c3830da8cd': <tethne.classes.paper.Paper at 0x10db7a090>,
#  '1a4034a1bad2f4bf67fe66243a54b30d': <tethne.classes.paper.Paper at 0x1172e4090>,
#  '675a40498fa85ca9974b831300f54bbf': <tethne.classes.paper.Paper at 0x10db2a4d0>,
#  '4f585f866d663f7ebe5738ca5f21f429': <tethne.classes.paper.Paper at 0x10d79b250>,
#  '65d16b167b2c013bf944b31d219c4a33': <tethne.classes.paper.Paper at 0x10f64c590>,
#  'f86be6e6f98dbfddc1fdac8fa8a6b3ae': <tethne.classes.paper.Paper at 0x120002850>,
#  '1733ab6c9347b01f9732e4bed0b170f3': <tethne.classes.paper.Paper at 0x1172e4e10>,
#  '16fbb47c15e8839deea1bc0d2d4dfb27': <tethne.classes.paper.Paper at 0x10d79bb10>,
#  '38900b218b2d75c6190a798039b8a2ee': <tethne.classes.paper.Paper at 0x10d825290>,
#  'e5205e56f034f87a100df7bc4e409050': <tethne.classes.paper.Paper at 0x11d274910>,
#  'a62eda50896d995ab624726bd6b7abda': <tethne.classes.paper.Paper at 0x1215e0a90>,
#  'a04edfd3228a54a8be8e8c7bfa3e2ced': <tethne.classes.paper.Paper at 0x11564c850>,
#  '14e5dd1fc420c38847c2f1ba7d989fae': <tethne.classes.paper.Paper at 0x10dceddd0>,
#  'db86342f990e021c959e49a617e0914a': <tethne.classes.paper.Paper at 0x11b231250>,
#  '31cc711cfe2a42d1a99f7680a461ff33': <tethne.classes.paper.Paper at 0x10dca8210>,
#  '24ec848fb6566821a05084d1ac5a7b03': <tethne.classes.paper.Paper at 0x120002cd0>,
#  '8cc2dc900b70be3b83b171769924f55b': <tethne.classes.paper.Paper at 0x11564c990>,
#  '9ddebd18570810b45596005aee9c4f15': <tethne.classes.paper.Paper at 0x11fea1ad0>,
#  '633c6a3f8ec44fe223ddb9affa3b1159': <tethne.classes.paper.Paper at 0x10deb41d0>,
#  '8fb8ab51ac7d834f6f593be1c6d64441': <tethne.classes.paper.Paper at 0x109584510>,
#  '6398f71df1639b8e3af7b48e1d6f0699': <tethne.classes.paper.Paper at 0x10d731e10>,
#  '649c02bd5207228b68c494ad7a9cbdfb': <tethne.classes.paper.Paper at 0x10aa3e610>,
#  '4e02b5a1ee9fec6dccbc712f08db5317': <tethne.classes.paper.Paper at 0x10deb4d90>,
#  'faa14f8b519e31727d01868cb93346c5': <tethne.classes.paper.Paper at 0x10dbd70d0>,
#  '07f35cf544d7fd407537ca6311dbb447': <tethne.classes.paper.Paper at 0x110397ed0>,
#  '0ca41514695dce16480803a2aacf0a69': <tethne.classes.paper.Paper at 0x108fc3190>,
#  '13169d19f28961dc65c4092a950dd963': <tethne.classes.paper.Paper at 0x1172e4990>,
#  'f6127e2d8b4d182600ef9f5d8bd0c1bc': <tethne.classes.paper.Paper at 0x10da60b90>,
#  'c6758bbd2282e97d24b488e1963e6cb2': <tethne.classes.paper.Paper at 0x1200025d0>,
#  '26e1fbf5ec193a28fbda8641cade7226': <tethne.classes.paper.Paper at 0x11d0a67d0>,
#  '0a9838a46b0297e3739708bde8f3d574': <tethne.classes.paper.Paper at 0x113b0c690>,
#  '933087d99b942f9902d04dc7247f63c6': <tethne.classes.paper.Paper at 0x11564c910>,
#  'e8d269b9e497fc55e829817ebd798a05': <tethne.classes.paper.Paper at 0x108ae5650>,
#  '418e582a46ca2f266ca81fba0af648ae': <tethne.classes.paper.Paper at 0x11d0a6c10>,
#  'b1596bbef386f963d5795a4e4d9c74d5': <tethne.classes.paper.Paper at 0x10d760490>,
#  'd1a300886453969144981d4698f3f91d': <tethne.classes.paper.Paper at 0x10dab31d0>,
#  '492dcead30c9149002ab4c6f31788199': <tethne.classes.paper.Paper at 0x11fea1690>,
#  'd5924f10f6c94c6bc1a9459ad7065795': <tethne.classes.paper.Paper at 0x10aa27a10>,
#  '7e63f91dddd7ea78af5898ae5e8740a7': <tethne.classes.paper.Paper at 0x10dcedf90>,
#  '2ccd75de2ac937db209d1779ed7a87b7': <tethne.classes.paper.Paper at 0x11fea1cd0>,
#  'f60f8acf2845b0390f4846afd6876bdd': <tethne.classes.paper.Paper at 0x10dd110d0>,
#  'ad095c4286a1f2fe2be1861b9c676207': <tethne.classes.paper.Paper at 0x10d7d3110>,
#  'f7657125084a128d77245e0d1294dcf7': <tethne.classes.paper.Paper at 0x10deb4cd0>,
#  '7fd4e2ccb1fab157eba1afa65f84e1ae': <tethne.classes.paper.Paper at 0x1172e4cd0>,
#  '7c099e89e803b997bcfd6be972b2653a': <tethne.classes.paper.Paper at 0x11d0a6f90>,
#  '236eb21e78831deb2daa076a04071238': <tethne.classes.paper.Paper at 0x1172e4350>,
#  'c24886770d4eea37847cf425127b4c1a': <tethne.classes.paper.Paper at 0x1172e4e90>,
#  '812c93f2934f5a69bb1a94fb778c3afe': <tethne.classes.paper.Paper at 0x10da03390>,
#  '02dab3e608f30a4d08d666a7d46bbe4c': <tethne.classes.paper.Paper at 0x10dbee290>,
#  '1b9589ea1db6c67a73f0bc9a87383f89': <tethne.classes.paper.Paper at 0x109637950>,
#  '5b018cc2c8ec04c8985c4ed7e45bb406': <tethne.classes.paper.Paper at 0x10b8b7490>,
#  '3b1d20a386d04cf3ea03e6f13195906e': <tethne.classes.paper.Paper at 0x11564ced0>,
#  '2fe975a44f58b0828a0d6edcfd0585b7': <tethne.classes.paper.Paper at 0x10dab3150>,
#  '5286c7bd472630f803eb9f24c9dcbfcd': <tethne.classes.paper.Paper at 0x10d76ba50>,
#  '1c59eb70454ab9aca43f16365419093a': <tethne.classes.paper.Paper at 0x10afcba50>,
#  '46230be5cd9016721f4df3250223acd7': <tethne.classes.paper.Paper at 0x11b231ed0>,
#  '5a0aaf48301956afed9461ee10fe975b': <tethne.classes.paper.Paper at 0x10dd6f2d0>,
#  '5e3bd33c521191ec839eb6a3ad1888e4': <tethne.classes.paper.Paper at 0x10d79b590>,
#  'e0cf0a9927200419023d6c4639ec85c6': <tethne.classes.paper.Paper at 0x1172e4b90>,
#  '79d8484bb632487c1ae72d99fab6f2f5': <tethne.classes.paper.Paper at 0x10f64c890>,
#  '667345be5608024359fd93733cbad95c': <tethne.classes.paper.Paper at 0x10ddc1390>,
#  '3b454f6d74748c197929467b88ad0660': <tethne.classes.paper.Paper at 0x120002390>,
#  '6190609fb8fcceb3170e00161bd1b87c': <tethne.classes.paper.Paper at 0x10d98f190>,
#  'ffe0414df0fbe1b6328fa12ed4c9def2': <tethne.classes.paper.Paper at 0x120002310>,
#  'ad8bbe9e363c6f5723d42a50c5c2b256': <tethne.classes.paper.Paper at 0x11e84a950>,
#  '413c81681d03c7677f3b1d0e178e6843': <tethne.classes.paper.Paper at 0x10d79b610>,
#  'c193b91b100fe2e73a082b40c73d553a': <tethne.classes.paper.Paper at 0x11564cc50>,
#  '0ddc7f82f1f51d9b4e4f4e7adb381436': <tethne.classes.paper.Paper at 0x10dd6f090>,
#  'bf7b6449b17b93c49ee75e22aa4926d9': <tethne.classes.paper.Paper at 0x10f00b110>,
#  '374b5fd1fd5f986bdd24fa5fbe3899c9': <tethne.classes.paper.Paper at 0x10d79be50>,
#  '633d1983e2fe12d2a57d58c5ad4906e2': <tethne.classes.paper.Paper at 0x110397690>,
#  '80069019137dbae1ecae099332011ca4': <tethne.classes.paper.Paper at 0x10d79bf10>,
#  '46e3f327214d9c6bddfc55215773abff': <tethne.classes.paper.Paper at 0x10d8bc150>,
#  '8df364ce8fcef3eef4e129fd909f528a': <tethne.classes.paper.Paper at 0x11d274650>,
#  '4352ee606be521a3c8891ae7cb15ff58': <tethne.classes.paper.Paper at 0x10da03150>,
#  '419600e7d1596ad0dfc2b76fa0f1a291': <tethne.classes.paper.Paper at 0x10ba3b090>,
#  'd4ca9b8169d5857b3244def5a87f3d14': <tethne.classes.paper.Paper at 0x11564cc10>,
#  '80e81a090f9cf7e6a0c9662a22ed164e': <tethne.classes.paper.Paper at 0x1215e0510>,
#  'c7788e5ddd169ee3689320fb1799eb82': <tethne.classes.paper.Paper at 0x10d7c9710>,
#  'da70fe1e58bc2f707d5cbd8dc412372a': <tethne.classes.paper.Paper at 0x11d2747d0>,
#  '88ff3ae3b467a4f1cd3306ce85a0e13d': <tethne.classes.paper.Paper at 0x110397110>,
#  'e651e687076b3b5fd2dea3af3681675c': <tethne.classes.paper.Paper at 0x10966a090>,
#  '1ec13754be83251405a85480586b8f7c': <tethne.classes.paper.Paper at 0x10d7d31d0>,
#  '75b3cea7d33e9e829e1eba8700b7fa65': <tethne.classes.paper.Paper at 0x10a877810>,
#  '2a0056f331799609e2e33030d0d451d0': <tethne.classes.paper.Paper at 0x1172e4790>,
#  '71d2b0ce069ae669efc9214f83563d87': <tethne.classes.paper.Paper at 0x10d760050>,
#  '2c4fc3650be48a0cf735b0c8c132b09b': <tethne.classes.paper.Paper at 0x10de57110>,
#  '5629bee225dbd4e74f75caec825d328c': <tethne.classes.paper.Paper at 0x10d79bc90>,
#  '6676d33f8e6201d5ce8dbf5fa700b875': <tethne.classes.paper.Paper at 0x120002e50>,
#  '937bad39251de82d778dff9d46892424': <tethne.classes.paper.Paper at 0x1172e4d90>,
#  '7cfe31ee8c290c001d5eeb0d5270501e': <tethne.classes.paper.Paper at 0x10d8e0110>,
#  '5a27b252a98c31a0c42137566c398bbc': <tethne.classes.paper.Paper at 0x10961cfd0>,
#  'a3d9045309589f9cfcd31b1a36418102': <tethne.classes.paper.Paper at 0x10bc3e190>,
#  'e4d62736ac84611148bffe802e01d7cf': <tethne.classes.paper.Paper at 0x10bcea110>,
#  'b9cd7bd5f38abdbc92871576d312aaeb': <tethne.classes.paper.Paper at 0x10dcede90>,
#  'dd207f67e8f62c5750d41ad649b1920c': <tethne.classes.paper.Paper at 0x10db85e10>,
#  '50fdf22c0c24656a9bdac94ebf61ba09': <tethne.classes.paper.Paper at 0x10da03a90>,
#  '5966d39e75038420a063099ce3181f27': <tethne.classes.paper.Paper at 0x10d7c96d0>,
#  '69a5d174ab94166f8d887398078ca0d7': <tethne.classes.paper.Paper at 0x10dde4290>,
#  '5ea6462c791675b7b2b0194e587e082f': <tethne.classes.paper.Paper at 0x110397850>,
#  '6e6d061f52ed6e067ff691d9fb6b640b': <tethne.classes.paper.Paper at 0x10db20c10>,
#  'fe4a31dc654e88ecd6cbc8cf4a89cc37': <tethne.classes.paper.Paper at 0x1172e4f50>,
#  'b8a81faac40a35a73c5de486a8039b2e': <tethne.classes.paper.Paper at 0x10df4c290>,
#  '49ba512f3fcf0cfd10e5067561743257': <tethne.classes.paper.Paper at 0x10da033d0>,
#  '72d60eaed56c65ad6bcbaedcea70a6f6': <tethne.classes.paper.Paper at 0x10dceda10>,
#  '2408a4702628481ecc197841fbea90f2': <tethne.classes.paper.Paper at 0x10d7d3a90>,
#  'bd82f943bf223f15d819dcb8022c538e': <tethne.classes.paper.Paper at 0x11e84a510>,
#  '9bcd01bcfdf20910dc0acca5e3a6062e': <tethne.classes.paper.Paper at 0x10dbcb350>,
#  '93956f781d1642e478385512a6578c78': <tethne.classes.paper.Paper at 0x10de63e50>,
#  '85162ef4d1712b217b0247198ea78b39': <tethne.classes.paper.Paper at 0x10dcedfd0>,
#  'aa3b47b5e1d544975525ef408b162b88': <tethne.classes.paper.Paper at 0x11d0a6ed0>,
#  '6cee975644df79ad2a495fc681b42a8a': <tethne.classes.paper.Paper at 0x120002550>,
#  'f590f3a3c8ce82aa787dc42f22cd3cd5': <tethne.classes.paper.Paper at 0x1103971d0>,
#  '16966e3fa71b4ab6418ba3ccfcaedd34': <tethne.classes.paper.Paper at 0x10d86b0d0>,
#  '9ea17b78ff4f05a2c9cfb94067c66791': <tethne.classes.paper.Paper at 0x10d7d3f50>,
#  'c938abe7caa2666a8ddc22bec27f89cd': <tethne.classes.paper.Paper at 0x10bf94110>,
#  '6c9ab177518b3e12b92e3988cf34f4a8': <tethne.classes.paper.Paper at 0x10deb4a50>,
#  '95d822c32f44c2a54cdf5449f00c000c': <tethne.classes.paper.Paper at 0x10d961250>,
#  'f439895a4a7c042e7fd0389ea072962d': <tethne.classes.paper.Paper at 0x1215e08d0>,
#  'cf80a2065703b02321be97cf2f992b68': <tethne.classes.paper.Paper at 0x10dd86310>,
#  'b2351e84bf27a94eb89a17cbb56579f5': <tethne.classes.paper.Paper at 0x10ddcd1d0>,
#  '317985d27ec46b86da6036d9f64fb318': <tethne.classes.paper.Paper at 0x10db630d0>,
#  '485a9cf9c16942d56221ca0a5a9c4632': <tethne.classes.paper.Paper at 0x10da60a90>,
#  '36a69ebfd54a6ca25cf78c80f821b9dc': <tethne.classes.paper.Paper at 0x10d7d3550>,
#  '2e69c149df14e0e8b30db6547394586c': <tethne.classes.paper.Paper at 0x10d79bf50>,
#  '230b3b632ee589c8abfa730df00b7881': <tethne.classes.paper.Paper at 0x10da03c10>,
#  '6bc7a3df96b0a7ce44fab6bf156ad7e6': <tethne.classes.paper.Paper at 0x11b231350>,
#  '2c062ae712388cd913eb66c939fc7955': <tethne.classes.paper.Paper at 0x11fea1fd0>,
#  '75a2f85ec3f729d7a8155bedfb8535e4': <tethne.classes.paper.Paper at 0x11d274490>,
#  '40054191ee5a92445a13eea2c90ec914': <tethne.classes.paper.Paper at 0x10db85110>,
#  'bee0952754a98086230155a12f7749db': <tethne.classes.paper.Paper at 0x11d0a6390>,
#  '56d1003815a6b8c3ad070a0453424e1f': <tethne.classes.paper.Paper at 0x11b231550>,
#  '2d7e3602a1be6d0b8579e63c05503cae': <tethne.classes.paper.Paper at 0x11564ce50>,
#  '92e6ff538c4352e109266b28960bfa7c': <tethne.classes.paper.Paper at 0x10dc9c110>,
#  '22a6e5bdd1f3ad4151d62963445e48e3': <tethne.classes.paper.Paper at 0x1215e04d0>,
#  'f51c4ef6c961e6e161d8592bfb5d4d76': <tethne.classes.paper.Paper at 0x10db85250>,
#  'd5ee52e3879ef2bb467d4ce68e8261be': <tethne.classes.paper.Paper at 0x10d7c99d0>,
#  'c18c3d6bf63a015babdcd258de78912d': <tethne.classes.paper.Paper at 0x10da603d0>,
#  '5bd17253235741c03a7e3752c7487dcd': <tethne.classes.paper.Paper at 0x110397450>,
#  'dad133b3bb40fa04b4e98afc840a6e3e': <tethne.classes.paper.Paper at 0x10d79b710>,
#  '06b84181dd1c424f2dd1133b3dc40528': <tethne.classes.paper.Paper at 0x10d7be210>,
#  '57d9eff89758296a39c8404f2f52ecfb': <tethne.classes.paper.Paper at 0x10deb4310>,
#  'db185ed5c5252d5fc75d8158bb27ff5f': <tethne.classes.paper.Paper at 0x10dea9150>,
#  '1eff88e66e4ae165162d02dcc3dfd2c1': <tethne.classes.paper.Paper at 0x11564ce10>,
#  'aa9bc2d9b77d600f123ab96c4fa4fddb': <tethne.classes.paper.Paper at 0x10deb4f90>,
#  '193ae720ba7ef73ab5861568a1e9d8ba': <tethne.classes.paper.Paper at 0x120002a50>,
#  '17030dfd45e15d159569fe5167eed89d': <tethne.classes.paper.Paper at 0x120002d50>,
#  '4ffab289d44f2ded22bd5976f94f9ad6': <tethne.classes.paper.Paper at 0x10dd6f890>,
#  'e9c6334f6646ede755e9c2535f2abcf6': <tethne.classes.paper.Paper at 0x11e84a150>,
#  '39d5ad1687bd71345747bdf1d1a4b4b1': <tethne.classes.paper.Paper at 0x11fea1790>,
#  '088aac9d8db3fbac1453d0213b754376': <tethne.classes.paper.Paper at 0x11d274610>,
#  'b6168c1ae8226f533a1d375d6430b030': <tethne.classes.paper.Paper at 0x10dc863d0>,
#  'ee0d8c722ac1ac940ae6cca8545ac194': <tethne.classes.paper.Paper at 0x11564c790>,
#  '5bdd9571aa50f0d1b5928aad99f954d9': <tethne.classes.paper.Paper at 0x10d8253d0>,
#  'c30f3dd95d2c7061c564920ead12a642': <tethne.classes.paper.Paper at 0x10db85fd0>,
#  '8eeb726059729184cc076ec03b09d28d': <tethne.classes.paper.Paper at 0x10dd4c410>,
#  '1dde48ae00566d6d3503603c9d9d0830': <tethne.classes.paper.Paper at 0x11b231110>,
#  'e9d67c1b8e76b8b1871834db9581570a': <tethne.classes.paper.Paper at 0x10d7d3c50>,
#  '7d02ee5f61e37947c1fa64f42ea5d42a': <tethne.classes.paper.Paper at 0x1200027d0>,
#  'defde6fa2577f353e06e72240ab094e5': <tethne.classes.paper.Paper at 0x10d7e0510>,
#  '7f6327ee687040262e5e232ee0e6cb20': <tethne.classes.paper.Paper at 0x120002050>,
#  '3678035b8167bb26fb53e31d11882fa6': <tethne.classes.paper.Paper at 0x10db85a90>,
#  '148a59ce33c0b836f6ec1ce9e24fe44c': <tethne.classes.paper.Paper at 0x10d9b3550>,
#  'd68340c9cc1b28d16c6473673637065e': <tethne.classes.paper.Paper at 0x10d80ead0>,
#  '4f4003570787c0b8defc1ea967dd55f5': <tethne.classes.paper.Paper at 0x11e84ae10>,
#  '2a5d6018f22a4aa46e811a79279d4555': <tethne.classes.paper.Paper at 0x11e84ae50>,
#  '1caedb99f8f7e5bfc7ede9ddd9a80749': <tethne.classes.paper.Paper at 0x11564c890>,
#  'f3a206bd66fa2fc99d0179c1313ddeec': <tethne.classes.paper.Paper at 0x10bf9fb10>,
#  '7fd5c60a648b61209859260b69603aca': <tethne.classes.paper.Paper at 0x10db85390>,
#  '89864467e2fed8b886f428db34f29e6b': <tethne.classes.paper.Paper at 0x11fea16d0>,
#  '16f4d658ff69560aeb9df21cc1502d23': <tethne.classes.paper.Paper at 0x10d7d37d0>,
#  '5b272c0023a6b7265dbbed9d30955820': <tethne.classes.paper.Paper at 0x1082c2910>,
#  '19ebaea692720f2dbb8a145ea101fac1': <tethne.classes.paper.Paper at 0x10da60850>,
#  '789f45277290923894ac0a33dba5812e': <tethne.classes.paper.Paper at 0x10d9be310>,
#  '1094a8a1b030c4ddb87ee6f65d6ec61c': <tethne.classes.paper.Paper at 0x10da03590>,
#  '051e21d863cce6efbfd5daaeb051168e': <tethne.classes.paper.Paper at 0x10dda9110>,
#  '8e3522670b8d8eaec3973bb1a523596f': <tethne.classes.paper.Paper at 0x10da03fd0>,
#  'e68f13708910779810b9cf00753da130': <tethne.classes.paper.Paper at 0x10da60450>,
#  '5748bebb2ba516cf45f39081007bfdf4': <tethne.classes.paper.Paper at 0x11d0a6fd0>,
#  '71dabc59782b7f67ba3411efbc4d8465': <tethne.classes.paper.Paper at 0x10da60c50>,
#  '2fe4487812cc315c39aebf0d0b7a12ed': <tethne.classes.paper.Paper at 0x1215e09d0>,
#  '7c502450526772c52ea56e5122f523d8': <tethne.classes.paper.Paper at 0x10d825250>,
#  'aa4c43593cc13cb9b37cac4c1a3180a1': <tethne.classes.paper.Paper at 0x10dbd7110>,
#  '0fe1ff0ce89c2314a8208d7c3f57b61c': <tethne.classes.paper.Paper at 0x10da03f50>,
#  'd8221836ac85119bf6fa7f289131426c': <tethne.classes.paper.Paper at 0x10dced350>,
#  'a36b4944349166c195df60a22bb81899': <tethne.classes.paper.Paper at 0x10deb4290>,
#  'cd7d915c2ff64ee2c3eda235cb092ea2': <tethne.classes.paper.Paper at 0x10db851d0>,
#  'fb27fb0e807790b8a59fdc6e7fb9cbed': <tethne.classes.paper.Paper at 0x10dc91550>,
#  '5d132e7d0911a9239176aa42b29cb68f': <tethne.classes.paper.Paper at 0x10da03e90>,
#  'f48d35ee45019b422fdefa67912f9d14': <tethne.classes.paper.Paper at 0x10d7c9990>,
#  '9ea3e2d4772238addb805e6c3c503932': <tethne.classes.paper.Paper at 0x10bf7b350>,
#  '778d9bb0b5f03321320460cc98e3fdd1': <tethne.classes.paper.Paper at 0x10d79b410>,
#  'cbdb5de0176273c047bd9f64113853ee': <tethne.classes.paper.Paper at 0x11b231f10>,
#  'e4578dd26f0595b75a36255e671f8007': <tethne.classes.paper.Paper at 0x1215e0250>,
#  '798e20c3f5a24d6341193df77f9ab81f': <tethne.classes.paper.Paper at 0x10d79be10>,
#  '4fc821af47731bf7ad9edf667f5e72a8': <tethne.classes.paper.Paper at 0x11fea14d0>,
#  '175c753939dd60c66e20f8ea4ecdba80': <tethne.classes.paper.Paper at 0x10d7031d0>,
#  'bc786fc1bef27465871c73fa11325202': <tethne.classes.paper.Paper at 0x10d7c9550>,
#  '4a3027327935a58dbfc7944f83192083': <tethne.classes.paper.Paper at 0x10db850d0>,
#  'd4fe6a518c49c9d4e255a38fa66d3fdd': <tethne.classes.paper.Paper at 0x10ba23050>,
#  '0d47ebca4ea17c548e2ffd88b92454b9': <tethne.classes.paper.Paper at 0x11e84a4d0>,
#  '8575c91d03699bb95b153b41889ec69c': <tethne.classes.paper.Paper at 0x1215e0350>,
#  '77eacb70f6b16b094bc88710140b3672': <tethne.classes.paper.Paper at 0x10deb4250>,
#  '6b46b9a441c168428fca187c52a0200d': <tethne.classes.paper.Paper at 0x10db85ed0>,
#  '6b2fc862fe7942c811111363f8766ecf': <tethne.classes.paper.Paper at 0x10ddc1450>,
#  '4a3ce163fd3fd64fdebf8a85f909a786': <tethne.classes.paper.Paper at 0x11e84ac50>,
#  '46b2f3ecae9780ffb6e01f40f823e5b1': <tethne.classes.paper.Paper at 0x10f64cc90>,
#  '958c3fb4f5073c14fe11dc190bb32284': <tethne.classes.paper.Paper at 0x10dad70d0>,
#  'b49554fcfedceca5ac1c67e1d7097b77': <tethne.classes.paper.Paper at 0x10dced410>,
#  '1d4623286eba93961526c1f6841ff8e6': <tethne.classes.paper.Paper at 0x10dbf9110>,
#  'fca2be7a0626637d5d479d212ae2e7eb': <tethne.classes.paper.Paper at 0x10a8f10d0>,
#  'bbe2b3879895d7c0d03175cbb263506e': <tethne.classes.paper.Paper at 0x10da60cd0>,
#  'd5d1c6e5d1d90bfe0849186b97064955': <tethne.classes.paper.Paper at 0x10d7c9ed0>,
#  '616751588f80858fd649035d173efc71': <tethne.classes.paper.Paper at 0x10da03b50>,
#  '0d51b1b13e05c55474f380a872913ead': <tethne.classes.paper.Paper at 0x10dd9d390>,
#  '65d8d9365e80cb8c6e887eb68e52a124': <tethne.classes.paper.Paper at 0x11d0a6490>,
#  'd5bfc597bc049596af24a2f8cfc120e6': <tethne.classes.paper.Paper at 0x11fea1b10>,
#  '12ef5ae73e8ba66639a7090e6f71b560': <tethne.classes.paper.Paper at 0x109516a10>,
#  '5dfbc5ba67110e63fe6536db9f2ce224': <tethne.classes.paper.Paper at 0x10d8f6490>,
#  'ffa0dea391d72376735a84a4b8d7bff3': <tethne.classes.paper.Paper at 0x110397310>,
#  '263a18fcf5bd042273ec145dfb0565a4': <tethne.classes.paper.Paper at 0x11564c410>,
#  'e91cfd61f8d152fb46999c1fd4be0ce5': <tethne.classes.paper.Paper at 0x110397c10>,
#  'bf0cdace1c2d3eb636021288cc41ebae': <tethne.classes.paper.Paper at 0x10dced150>,
#  '5ec26d3a5dfa1b536635a07711db809a': <tethne.classes.paper.Paper at 0x120002810>,
#  'c1ff7f484f5320bfe5329f44e6b0d925': <tethne.classes.paper.Paper at 0x107e5f610>,
#  'e0276a0c5a5da8a51daf387ada6ee2dd': <tethne.classes.paper.Paper at 0x10f64cd90>,
#  '3c54d1e93ccfd3fc242920a5ece1eac1': <tethne.classes.paper.Paper at 0x1215e0490>,
#  'd4fdde47266f4a533e9d030b0b2da644': <tethne.classes.paper.Paper at 0x10de571d0>,
#  'b811c53f9f1c789a41cb7ea8ccf53aee': <tethne.classes.paper.Paper at 0x10d7d3dd0>,
#  'e3b0bc3de02c40af8e8ad29fa0405918': <tethne.classes.paper.Paper at 0x10d7c9d90>,
#  '8fd74061073b051120545786fc087cbf': <tethne.classes.paper.Paper at 0x10deb4fd0>,
#  '9c8f0d1af18ace6391815a9c45a3a853': <tethne.classes.paper.Paper at 0x10d847190>,
#  '3df6d92f07c5d9a6153ddced431030bb': <tethne.classes.paper.Paper at 0x1172e4fd0>,
#  'c39adcff2ae71290c855ae8433ccde0a': <tethne.classes.paper.Paper at 0x1215e0d90>,
#  '04b94aec16d475dbc59721452143a389': <tethne.classes.paper.Paper at 0x10f64cbd0>,
#  '07e0b99c4bdefa3d89ef68832d983c7f': <tethne.classes.paper.Paper at 0x11564c2d0>,
#  'a32467c6397529be804ef9897e1b3660': <tethne.classes.paper.Paper at 0x10daa8310>,
#  '970245695506dbcc137ab44c0d5682c0': <tethne.classes.paper.Paper at 0x1172e4310>,
#  '62f924a3a038885f831474e883ef7067': <tethne.classes.paper.Paper at 0x11d0a6a10>,
#  '8ca8e2929db5120cfd3e6a6ba655ab42': <tethne.classes.paper.Paper at 0x1172e4bd0>,
#  'c2edb2cb94235d919e44db19ae29ee35': <tethne.classes.paper.Paper at 0x11e84ad10>,
# ...
#  '03b40fb66a372b292f9603b6370b3312': <tethne.classes.paper.Paper at 0x11564c650>,
#  'a095fb450a8494329f2af946a7183ea4': <tethne.classes.paper.Paper at 0x10f64c750>,
#  '1f3cb86308176c54994d975f62159565': <tethne.classes.paper.Paper at 0x10db85990>,
#  '71816a41858debe2c561a7989c5a8d06': <tethne.classes.paper.Paper at 0x10db854d0>,
#  '0d63678ce8f4e56b6a8ecaa243e52421': <tethne.classes.paper.Paper at 0x10d825fd0>,
#  '40194b5244ded41e4f85da69381d0a21': <tethne.classes.paper.Paper at 0x10d79ba10>,
#  'cf0c3213286fb2ea18aec3cfdbca6756': <tethne.classes.paper.Paper at 0x10f64cfd0>,
#  '442c2e3a75d129870b84dc1bcc8ad451': <tethne.classes.paper.Paper at 0x10dd6ff10>,
#  '4d8abf0937ca620d0348eb7bd84816e9': <tethne.classes.paper.Paper at 0x10d7d3350>,
#  '2609bf39c639568869e59f1a92e44f19': <tethne.classes.paper.Paper at 0x10df06290>,
#  'bdc828c2d2b09e01cf6723a5fe78eb80': <tethne.classes.paper.Paper at 0x1095ac790>,
#  '6906235a1544d8741d440675b82c0018': <tethne.classes.paper.Paper at 0x1148dcd10>,
#  'edacf68d4a7cbe4a4baf9f9d46432748': <tethne.classes.paper.Paper at 0x10defbb50>,
#  '5821f22982705e41388a213f5c48e8a3': <tethne.classes.paper.Paper at 0x10af8e490>,
#  '20bcca5abe3fe368afb343a3f7118f54': <tethne.classes.paper.Paper at 0x11fea1450>,
#  '1a48b5b129eb004923ab092dbf67b33d': <tethne.classes.paper.Paper at 0x108208a50>,
#  '5a96acb9bcd8d40d8f8384e75ccb9f54': <tethne.classes.paper.Paper at 0x10d703290>,
#  '75f1f272664fb9c558045d4cdce757c6': <tethne.classes.paper.Paper at 0x120002090>,
#  '6dc07743a16123b09503a2b0ea122f9a': <tethne.classes.paper.Paper at 0x10f64c610>,
#  'bc2ac0a57c96851ed32a4e23a8d0617b': <tethne.classes.paper.Paper at 0x11e84af90>,
#  'd240fb552ca6aad99f21f32a35ae84bf': <tethne.classes.paper.Paper at 0x10d904990>,
#  'c2d2be5570a4c00d4e1e96029e2f849a': <tethne.classes.paper.Paper at 0x10dced2d0>,
#  '1eab162c724feefe4f84ed7590202cf0': <tethne.classes.paper.Paper at 0x10db6e250>,
#  '8dbb214fe14e73fe946e7ae1cc53182e': <tethne.classes.paper.Paper at 0x10dced7d0>,
#  'f769540adbc15769d7a38a66b780860d': <tethne.classes.paper.Paper at 0x10da03690>,
#  'ec118d794121f7eed84cdf50947d874c': <tethne.classes.paper.Paper at 0x10da03610>,
#  '0bc2bc0cd8363c3dea8dca0043f20100': <tethne.classes.paper.Paper at 0x10da604d0>,
#  'dc3ca1eaf2581958626a20ee9f94f36e': <tethne.classes.paper.Paper at 0x10de05110>,
#  'ccb1690a7552caab4091871d01b7bf75': <tethne.classes.paper.Paper at 0x10d7d3e90>,
#  '84bfa3c3088157aa13f20c498cab5fb4': <tethne.classes.paper.Paper at 0x10dd4c0d0>,
#  '8dbc0f6d9c83254aaf351eadd4677346': <tethne.classes.paper.Paper at 0x10da60ed0>,
#  '9d90d6cc09ae78ba33a1935deaedefd8': <tethne.classes.paper.Paper at 0x10def0210>,
#  '04b7b3418390a707a13039598b86f4ba': <tethne.classes.paper.Paper at 0x10de1e090>,
#  'c918d0d1357a2fd96542c5c4c4eef026': <tethne.classes.paper.Paper at 0x10d7d3c10>,
#  'b480bc656569ba2f335df60aa734c779': <tethne.classes.paper.Paper at 0x1094fe690>,
#  'f8024d8886b4f02f04d3bf7d6797f7e6': <tethne.classes.paper.Paper at 0x10db85d90>,
#  'c3337e810847d869076b2161db8d67a1': <tethne.classes.paper.Paper at 0x10beb3450>,
#  '08f97900af3f9440ff38e08cb4a77d0d': <tethne.classes.paper.Paper at 0x10a465810>,
#  '00c921c1deabe86d3f35dd873e4beeaf': <tethne.classes.paper.Paper at 0x1172e4390>,
#  '4f9fb4b29bb49fbe2694c7499d90e937': <tethne.classes.paper.Paper at 0x10d81a290>,
#  '70bdc743837856a927e7682dcd529e28': <tethne.classes.paper.Paper at 0x10dd6f250>,
#  'ee999ab1e14c05e48afe70dc64427202': <tethne.classes.paper.Paper at 0x10dced310>,
#  '2d4c663915f4a5182ed4089b5a43b50b': <tethne.classes.paper.Paper at 0x11d274710>,
#  '1712eda9dd03de03f62d2ae90fe880db': <tethne.classes.paper.Paper at 0x120002dd0>,
#  '86762f88fa32e0bcd2a9272e947e7f66': <tethne.classes.paper.Paper at 0x10da60e10>,
#  '63eeb8b6f02db81c7aec2aec963246d7': <tethne.classes.paper.Paper at 0x10bfd91d0>,
#  '703facd5b18fc73afaa9cd62dc1edaca': <tethne.classes.paper.Paper at 0x11e84ab50>,
#  'f40d4f6a4a4d3dec276a54dbc480a87d': <tethne.classes.paper.Paper at 0x10dd6fd90>,
#  'f3450c13b6f7f9602dc83b4a0de313dc': <tethne.classes.paper.Paper at 0x10d825190>,
#  'ecabe5fbab3bd0f5e0099c156c4a8337': <tethne.classes.paper.Paper at 0x10da03310>,
#  '297cded08379778e877c71999507fdb8': <tethne.classes.paper.Paper at 0x10d961210>,
#  '44b9cab8fd9b147279c696d115932f29': <tethne.classes.paper.Paper at 0x1172e4290>,
#  '8275571612a8ab027d4e3b766c38a39b': <tethne.classes.paper.Paper at 0x10dcfa150>,
#  '1cfb1346da286758afb2802733c203ad': <tethne.classes.paper.Paper at 0x1215e0050>,
#  'c9712206879c6c290ec07bd0355af6f6': <tethne.classes.paper.Paper at 0x106740e90>,
#  'd83819bc6daf9a9e0a5ff76ad9da7b14': <tethne.classes.paper.Paper at 0x10d90f490>,
#  'f59bb0744e7c87d436ecb2fe52c7165f': <tethne.classes.paper.Paper at 0x10dd7a090>,
#  'd9341cc44881540da71b06146d97ac01': <tethne.classes.paper.Paper at 0x11e84a290>,
#  '67d2e046e4c51e4ecc50329915389a1c': <tethne.classes.paper.Paper at 0x10da03b90>,
#  'a8508020d9f579635224b423186d392f': <tethne.classes.paper.Paper at 0x1095ac750>,
#  '53ce843081ed294516f89d22dedd967f': <tethne.classes.paper.Paper at 0x1200020d0>,
#  '0f6a14bcdba7563fd0f2f08de6086eda': <tethne.classes.paper.Paper at 0x10d948910>,
#  '184a03391a7650e8c57ec0afea4022b3': <tethne.classes.paper.Paper at 0x10aa3e5d0>,
#  '70529d0a73bf9fa3ca0f74f6f96772dd': <tethne.classes.paper.Paper at 0x10dcede10>,
#  'bf07aad39e279bc4d7e455ae1fc1ce1d': <tethne.classes.paper.Paper at 0x10de7b050>,
#  '34de058c7e741e32dc14365d74ccce7e': <tethne.classes.paper.Paper at 0x10deb4990>,
#  'd723c89c540050180395f1b708d4b3fd': <tethne.classes.paper.Paper at 0x10d7e0910>,
#  '681fb980a198f3c9043cf0369a5c50c0': <tethne.classes.paper.Paper at 0x107429ad0>,
#  'e12b88c32aab54abc63c753042552b33': <tethne.classes.paper.Paper at 0x10dcbf110>,
#  '6785d600166d4d643e3b397774da5abb': <tethne.classes.paper.Paper at 0x1096379d0>,
#  '4b4132ee5248ace2fcab253532dabda7': <tethne.classes.paper.Paper at 0x10da03d50>,
#  '8271e83433ef94ca69622c26adb13077': <tethne.classes.paper.Paper at 0x10d7c9310>,
#  'cfd2cd045d4a108cdf75f288361a12fa': <tethne.classes.paper.Paper at 0x109516a50>,
#  '777804fd669d4fdd7ef0a96996eba966': <tethne.classes.paper.Paper at 0x11b2317d0>,
#  'bccb4776ba6ae8b647f54f1e0df2a75e': <tethne.classes.paper.Paper at 0x10dced890>,
#  '035af63ed15bab37646e7fe6f7c55f8a': <tethne.classes.paper.Paper at 0x10d8814d0>,
#  '6749570b823ba110efde67bde4913283': <tethne.classes.paper.Paper at 0x10ba2f0d0>,
#  '8d9047a80acbb7ac1e830cbc5cc86465': <tethne.classes.paper.Paper at 0x10d825f50>,
#  'e2adf0ffe3146987a627661a42f9a81b': <tethne.classes.paper.Paper at 0x10d7d38d0>,
#  'c06dc0950335d63b0ca34a3ab6d4ce63': <tethne.classes.paper.Paper at 0x10df41550>,
#  '00577470730b56077fecedfb58637f3f': <tethne.classes.paper.Paper at 0x10db85d10>,
#  'e28212638a323d96b08fe9d2afbe1185': <tethne.classes.paper.Paper at 0x1172e4f90>,
#  '2ee5d4635e0166e7c2e1ed75615fdd93': <tethne.classes.paper.Paper at 0x10d8257d0>,
#  '177ee127ab86671cbdfd12bd3d4597a7': <tethne.classes.paper.Paper at 0x10da60990>,
#  '9571d4335e6f080d30d30bdb4e6f70de': <tethne.classes.paper.Paper at 0x1172e4690>,
#  '599349fce98580f724d8cdcb58e9450c': <tethne.classes.paper.Paper at 0x10f64c0d0>,
#  '534a493dd3a2cbd67e1786f0a526fd2e': <tethne.classes.paper.Paper at 0x11b231710>,
#  'ac06453bb77c3957739c6f52ffe2302d': <tethne.classes.paper.Paper at 0x10f64c790>,
#  '1dd6253d687348527b9eb266b247fe86': <tethne.classes.paper.Paper at 0x11b231950>,
#  '9d824fe201af23f0bc24bc68d69a6690': <tethne.classes.paper.Paper at 0x10d7d3b50>,
#  'bf960cd24ce24ead0413bece462a700d': <tethne.classes.paper.Paper at 0x10744dad0>,
#  'ae3619b207193a4986739a98995c45ee': <tethne.classes.paper.Paper at 0x11fea1810>,
#  'fffb1aeda63be3eeb203c52fd72ab507': <tethne.classes.paper.Paper at 0x10d79b190>,
#  'c07c68327e466ee677bce30c56be2dda': <tethne.classes.paper.Paper at 0x10d7c97d0>,
#  '61867987f5cf738be593f36e531164ae': <tethne.classes.paper.Paper at 0x11d0a6b10>,
#  '858d85851510359ee2be64119a1e26cd': <tethne.classes.paper.Paper at 0x1215e0710>,
#  'c5fa5520c6087558c102a2250a5f0423': <tethne.classes.paper.Paper at 0x10deb4450>,
#  'c8df2b4c8825c40a8b7135dec20c6999': <tethne.classes.paper.Paper at 0x10da03910>,
#  'e2d47430a76bc6ebcd023fffc88a6485': <tethne.classes.paper.Paper at 0x106b61850>,
#  'f202f6aa75053be595308900a53d1402': <tethne.classes.paper.Paper at 0x10da03e50>,
#  'c4db5879aea4eeaccdae403b2863def6': <tethne.classes.paper.Paper at 0x10bd17090>,
#  '8338dadfdfa83b01dd82a3bbb6ac62cb': <tethne.classes.paper.Paper at 0x1172e41d0>,
#  'e2c34fa2d117d7d4e882b3fd558b6a54': <tethne.classes.paper.Paper at 0x10deb4b10>,
#  'cb9e867ea5a33c32e4046dbb4a106fc3': <tethne.classes.paper.Paper at 0x1042b2150>,
#  '6c5f0a3556428b7c80b95d377ad7f6a1': <tethne.classes.paper.Paper at 0x10d79b1d0>,
#  '74147ec4300ac91b3ec3aec91e681fdb': <tethne.classes.paper.Paper at 0x10d7c9e90>,
#  'e8d24f4df2fae33111907d892791c665': <tethne.classes.paper.Paper at 0x10df2a450>,
#  'c640daf10bda675bc41c13c43e201b75': <tethne.classes.paper.Paper at 0x11fea1710>,
#  '44db9b25822d126eca8b16ddbe2df289': <tethne.classes.paper.Paper at 0x11d274810>,
#  '8f948121a8680b00bb9ab5eeded4d4eb': <tethne.classes.paper.Paper at 0x10ddb5090>,
#  '761d168d8447067caeec7af6e9395851': <tethne.classes.paper.Paper at 0x1172e4110>,
#  '3cb3612d87377405e3671b5818f32ada': <tethne.classes.paper.Paper at 0x10dced750>,
#  '6a5a9fc88bc97f9b480029051d79debc': <tethne.classes.paper.Paper at 0x110397f90>,
#  '7594201005a630e72f82e077158fbb24': <tethne.classes.paper.Paper at 0x10d7c9250>,
#  '5c53337de646c44f1bce699758f9411c': <tethne.classes.paper.Paper at 0x10deb4550>,
#  '749c56633ca7c542dfe63846ff63d797': <tethne.classes.paper.Paper at 0x11fea1490>,
#  '356576cd256204294da58a03186f3e08': <tethne.classes.paper.Paper at 0x106946a10>,
#  '94a86b59604e6955fbde20f796fb9e64': <tethne.classes.paper.Paper at 0x10deb4950>,
#  '2d8c5bbd1696f829709015738489b517': <tethne.classes.paper.Paper at 0x10dd921d0>,
#  '44c8fb1ba547138d3a35c07ec20bb59e': <tethne.classes.paper.Paper at 0x10d760150>,
#  '81e339e531fa9cdb74ced5215c728230': <tethne.classes.paper.Paper at 0x1215e0bd0>,
#  '3d141950f01bd8b8854f8616809ac442': <tethne.classes.paper.Paper at 0x10f64cdd0>,
#  'f336e94fc991889e2cb447c580f77c73': <tethne.classes.paper.Paper at 0x11564c290>,
#  'b23146679a5dc2aac5b38502b53c1d3e': <tethne.classes.paper.Paper at 0x11fea1310>,
#  '62fb173c65cac4880abd16d83051b1b6': <tethne.classes.paper.Paper at 0x11fea1d10>,
#  '1ec8cbc0425df184dc61ae9444e903f2': <tethne.classes.paper.Paper at 0x10ba17190>,
#  'aae57c8986902f9da9f08142bf385056': <tethne.classes.paper.Paper at 0x10d961550>,
#  '27d3ab6e3a175c7b8dfad418e4b32882': <tethne.classes.paper.Paper at 0x110397c50>,
#  '965c769ec47aeb38ba7576ff2df419a7': <tethne.classes.paper.Paper at 0x10bf64250>,
#  '134494351f283bd4f4348db34aaa52d3': <tethne.classes.paper.Paper at 0x10deb4590>,
#  'f83eb10d439e371fce22f3bf92206479': <tethne.classes.paper.Paper at 0x110397710>,
#  'f538a187f46918a0237350ec5d840e5d': <tethne.classes.paper.Paper at 0x10d825410>,
#  'a9588a8143d5a3952b284d383769dc55': <tethne.classes.paper.Paper at 0x10d79b550>,
#  'e6b886d6810705fb90ffeb25e895ac61': <tethne.classes.paper.Paper at 0x10d825210>,
#  'f0513105a89225c92c60d9b5208031e0': <tethne.classes.paper.Paper at 0x120002410>,
#  '78524e3ee3b0f5c7ff458a4afc45aa9c': <tethne.classes.paper.Paper at 0x10deb4bd0>,
#  '5a762f8d74e0b431149685cf53a4e0cb': <tethne.classes.paper.Paper at 0x10de35190>,
#  '5f87321824b3c8984ec464d47fc96ee0': <tethne.classes.paper.Paper at 0x11d0a6a50>,
#  '396e3dc02b7e12e4d9f4aa17075b91b6': <tethne.classes.paper.Paper at 0x10df36190>,
#  'a9b2a4aa23939b6ed721f685b7a87dda': <tethne.classes.paper.Paper at 0x11d0a6a90>,
#  '4b963f7691f998d264b0ba4920efdd42': <tethne.classes.paper.Paper at 0x10980b810>,
#  '9276b4acfa4ed62e99f8b4672cabab46': <tethne.classes.paper.Paper at 0x113b0c750>,
#  '1ce0ca1bc4096106ae40bbd8b666e2ab': <tethne.classes.paper.Paper at 0x11564c550>,
#  'c847af894579627c8c0bac19d6989b92': <tethne.classes.paper.Paper at 0x10de9d210>,
#  'e427d1a23cee9f91895fe9b6c6cfa183': <tethne.classes.paper.Paper at 0x10da03490>,
#  '9fe509cab05cbd5030b5a22d6208b1fb': <tethne.classes.paper.Paper at 0x10962a410>,
#  '953597062ac28e6cb5c5678fe83cd33a': <tethne.classes.paper.Paper at 0x10f64c550>,
#  'e6fe3c13b755cc5dd6b770dba492c863': <tethne.classes.paper.Paper at 0x10dbd7190>,
#  '1b916779fe9f17633a481da2b2fb30b9': <tethne.classes.paper.Paper at 0x10d7c9dd0>,
#  'b9bb9c4d9c39b0c2a2111093f80fa44c': <tethne.classes.paper.Paper at 0x10d932350>,
#  '8a55e5b030fa49bbb39e8c92cdfacbb0': <tethne.classes.paper.Paper at 0x10d79b750>,
#  '58e07bf22f27f460ca6970c3555b19fd': <tethne.classes.paper.Paper at 0x10de1e0d0>,
#  'fa2c42794075773152ed1b79103e7298': <tethne.classes.paper.Paper at 0x120002bd0>,
#  '8e630ddd1f7320477f7aab28cacedc9f': <tethne.classes.paper.Paper at 0x10deb4d10>,
#  'bb949f6cb654b84af6b395f215d45cd5': <tethne.classes.paper.Paper at 0x10d7c9d50>,
#  'edb19d842ac28f4aa2d9723d8d8ded8f': <tethne.classes.paper.Paper at 0x10d825890>,
#  '8f5a8788c89b98047335644c6568e83e': <tethne.classes.paper.Paper at 0x11b2312d0>,
#  'bcdb26f35ebf045318a08ed24dff25dd': <tethne.classes.paper.Paper at 0x10d71b290>,
#  '09b99b21d53526cf210819338a83aefe': <tethne.classes.paper.Paper at 0x10dc06290>,
#  'a714e797750f27136c1c3acf1780b6c9': <tethne.classes.paper.Paper at 0x10ddc1ad0>,
#  'b139e1406e3e07f160f3f495f5dcfc02': <tethne.classes.paper.Paper at 0x11564c750>,
#  'd877f9013442671dab84dea23f74610e': <tethne.classes.paper.Paper at 0x11b231a10>,
#  'e27162c45929b580c1d74181a8d6044e': <tethne.classes.paper.Paper at 0x11fea1d50>,
#  '989b01283f8a1429d7e3a9c47095a698': <tethne.classes.paper.Paper at 0x10f64cb90>,
#  '95ad9ade16684fe0a3f66ff2edab0a30': <tethne.classes.paper.Paper at 0x11e84a750>,
#  'df192adb5fb3e534bae3f8f7c76145e2': <tethne.classes.paper.Paper at 0x10f64cd10>,
#  'c34a25e11f4683a6dd22beabd5eac9b0': <tethne.classes.paper.Paper at 0x10dd6fa50>,
#  'ee56d71bccc92abbcaa42cdad34ba3e4': <tethne.classes.paper.Paper at 0x10deb4b90>,
#  'e774391ef91181f9fa8f4f6811a130ad': <tethne.classes.paper.Paper at 0x10dcedc10>,
#  '34760d4c82fe9133a5a0f7de6985f6fd': <tethne.classes.paper.Paper at 0x10da60bd0>,
#  'db7063b4016b438dcd6b25b3ee9b63aa': <tethne.classes.paper.Paper at 0x10d7c9050>,
#  'd29c78635628c541bc1f481cbf91d0fe': <tethne.classes.paper.Paper at 0x106946910>,
#  '55043b6e81d2d22ee0b8bc26ebf7667b': <tethne.classes.paper.Paper at 0x10d79b390>,
#  '910aea5c597f85dda3c77c9cae40e5e5': <tethne.classes.paper.Paper at 0x10dd6fad0>,
#  '6bb35d1506acf6ad25a7f340bcf7df33': <tethne.classes.paper.Paper at 0x10dced110>,
#  'ff6d494a3097988059fafb3ea093cdf6': <tethne.classes.paper.Paper at 0x10952f310>,
#  'b6e21703d830ab39c578225691e151f9': <tethne.classes.paper.Paper at 0x11b231390>,
#  '7f2740147ac3ad1f4b448df8e67062dd': <tethne.classes.paper.Paper at 0x10d7d3ad0>,
#  'cdf0a1c81b3344c3d4b568a562705806': <tethne.classes.paper.Paper at 0x10dd6f8d0>,
#  '141f9c3f264f2a35f6a04cfb30a02751': <tethne.classes.paper.Paper at 0x10d898f90>,
#  'a63890442762b81a51b6c6dd6387a515': <tethne.classes.paper.Paper at 0x10dcca350>,
#  'd7a7faa1e24386669bb4a051d9a92e9b': <tethne.classes.paper.Paper at 0x10d79b2d0>,
#  '45804a721bf34dc6ca1773dca76d546d': <tethne.classes.paper.Paper at 0x10bfe5110>,
#  '51ffa567763686664e409b167e3e66ef': <tethne.classes.paper.Paper at 0x10dae0e50>,
#  'ee7bb00d57fa29cdf55fc5c81b3fcea7': <tethne.classes.paper.Paper at 0x11fea1610>,
#  '34b8b755a46ae00fc424f77297d3772c': <tethne.classes.paper.Paper at 0x10f863a10>,
#  'af15600ce116cbda2e8a5223557da9b7': <tethne.classes.paper.Paper at 0x1172e4dd0>,
#  'cc86b24021e9cbbbab47cdfeac1b8ce3': <tethne.classes.paper.Paper at 0x10d825310>,
#  '2b252b2a958a80aae271298ddd9a7e95': <tethne.classes.paper.Paper at 0x11e84a790>,
#  '2ccc6212713c687e6ea5d6ac197c7e80': <tethne.classes.paper.Paper at 0x10dd86c10>,
#  'e4117d445a82a9d5f6cb413572718983': <tethne.classes.paper.Paper at 0x10da602d0>,
#  '54417262a6eb98ef9ccf4b249cf1e536': <tethne.classes.paper.Paper at 0x10deb4c10>,
#  '9c1106d71696c16c136847a7172adbc0': <tethne.classes.paper.Paper at 0x11564c950>,
#  'f2d9e2fb69750a067e0770d94056933e': <tethne.classes.paper.Paper at 0x10d7d3c90>,
#  '7f20b1adb0f4b7a2d72745d0173580c0': <tethne.classes.paper.Paper at 0x10bf70590>,
#  ...}

# %%
def merge(P1, P2, fields=['ayjid']):
    """
    Combines two lists (P1 and P2) of :class:`.Paper` instances into a single
    list, and attempts to merge papers with matching fields. Where there are
    conflicts, values from :class:`.Paper` in P1 will be preferred.

    Parameters
    ----------
    P1 : list
        A list of :class:`.Paper` instances.
    P2 : list
        A list of :class:`.Paper` instances.
    fields : list
        Fields used to identify matching :class:`.Paper`

    Returns
    -------
    combined : list
        A list of :class:`.Paper` instances.

    Examples
    --------

    .. code-block:: python

       >>> import tethne.readers as rd
       >>> P1 = rd.wos.read("/Path/to/data1.txt")
       >>> P2 = rd.dfr.read("/Path/to/DfR")
       >>> papers = rd.merge(P1, P2, ['ayjid'])
    """

    combined = []
    del_P1 = []
    del_P2 = []

    for x in xrange(len(P1)):
        p_1 = P1[x]
        for y in xrange(len(P2)):
            p_2 = P2[y]
            match = True
            for field in fields:
                if hasattr(p_1, field) and hasattr(p_2, field):
                    if getattr(p_1, field) != getattr(p_2, field):
                        match = False
                        break

            if match:   # Add values first from P2 paper, then from P1 paper.
                new_p = Paper()
                for key, value in p_2.__dict__.items():
                    if value != '' and value is not None:
                        new_p[key] = value
                for key, value in p_1.__dict__.items():
                    if value != '' and value is not None:
                        new_p[key] = value

                del_P1.append(x)    # Flag for deletion.
                del_P2.append(y)

                combined.append(new_p)

    for x in xrange(len(P1)):
        if x not in del_P1:
            combined.append(P1[x])
    for x in xrange(len(P2)):
        if x not in del_P2:
            combined.append(P2[x])

    return combined

# %%
from tethne import Paper
