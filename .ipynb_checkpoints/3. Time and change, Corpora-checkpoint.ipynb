# %% [markdown]
# # Introduction to Tethne: Time and Change, Working with Corpora

# %% [markdown]
# In this workbook we'll start to analyze our data diachronically. To do that, we'll make use of a special object called a ``Corpus`` that provides some handy methods for organizing and indexing our ``Paper``s. We'll use the ``slice`` method to index our ``Paper``s temporally and across journals, and plot the distribution of **features** across those slice axes.

# %% [markdown]
# ## Before you start

# %% [markdown]
# * Download the Web of Science practice dataset from [here](http://devo-evo.lab.asu.edu/methods/tethne/datasets.zip), and store it in a place where you can find it. You'll need the full path to your dataset.
# * Complete the tutorial **"Simple Networks"**

# %% [markdown]
# ## Loading our WoS data

# %% [markdown]
# We'll use the Web of Science dataset that we used in our last workbook. Since this is a new workbook, we'll have to load it again. This time, instead of loading a list of ``Paper`` objects, we'll load a ``Corpus`` all at once using the **``corpus_from_dir``** function.

# %%
from tethne.readers import wos
datadirpath = '/Users/erickpeirson/tethne-notebooks/data/wos'
MyCorpus = wos.corpus_from_dir(datadirpath)

# %% [markdown]
# Think of a ``Corpus`` as a container for your ``Paper``s. Your ``Paper``s are still here; you can get a list of all of your papers using the **``all_papers``** method. That means it's easy to generate a simple network like we did in the previous notebook.

# %%
from tethne.networks import authors
cg = authors.coauthors(MyCorpus.all_papers())
print 'This graph has {0} nodes and {1} edges, just like before!'.format(len(cg.nodes()), len(cg.edges()))
# Out:
# This graph has 4313 nodes and 10567 edges, just like before!

# %% [markdown]
# Your ``Paper``s are also indexed. For WoS datasets, they are indexed by ``wosid`` (``UT`` in the original field-tagged data file).

# %%
MyCorpus.papers.keys()[0:10]   # The first 10 keys in the Paper index.
# Out:
# ['WOS:000255437400005',
#  'WOS:000225242500007',
#  'WOS:000074414100009',
#  'WOS:000268928200019',
#  'WOS:000305886800001',
#  'WOS:000084882700020',
#  'WOS:A1995RV72900015',
#  'WOS:000308634600013',
#  'WOS:000314781600006',
#  'WOS:000220323300004']

# %% [markdown]
# So if you know the wosid of a Paper, you can retrieve it from ``Corpus.papers``:

# %%
MyCorpus.papers['WOS:000305886800001']
# Out:
# {'abstract': 'Because of the lack of varieties for organic agriculture, associations of organic farmers in several European countries have begun cultivating landraces and historic varieties, effectively practicing in situ conservation of agricultural biodiversity. To promote agrobiodiversity conservation, a special list for "conservation varieties" was implemented in 2008 by the EU because for any exchange and marketing of seeds in the EU, a variety must be registered in an official catalog. Our study aimed at improving knowledge on the phenotypic diversity and evolution of such varieties when cultivated on organic farms in Europe, in order to better define their specific characteristics and the implications for the registration process. We assessed multi-trait phenotypic evolution in eight European landraces and historic varieties of bread wheat and in two pureline variety checks, each grown by eight organic farmers over 2 years and then evaluated in a common garden experiment at an organic research farm. Measurements on each farmer\'s version of each variety included several standard evaluation criteria for assessing distinctness, uniformity and stability for variety registration. Significant phenotypic differentiation was found among farmers\' versions of each variety. Some varieties showed considerable variation among versions while others showed fewer phenotypic changes, even in comparison to the two checks. Although farmers\' variety would not satisfy uniformity or stability criteria as defined in the catalog evaluation requirements, each variety remained distinct when assessed using multivariate analysis. The amount of differentiation may be related to the initial genetic diversity within landraces and historic varieties.',
#  'accession': 'a81ddf8c-2bb7-4f6a-a68f-bf8483b46b56',
#  'atitle': 'Multi-trait evolution of farmer varieties of bread wheat after cultivation in contrasting organic farming systems in Europe',
#  'auinit': ['JC', 'E', 'S', 'N', 'N', 'V', 'I'],
#  'aulast': ['DAWSON',
#   'SERPOLAY',
#   'GIULIANO',
#   'SCHERMANN',
#   'GALIC',
#   'CHABLE',
#   'GOLDRINGER'],
#  'auuri': None,
#  'ayjid': 'DAWSON JC 2012 GENETICA',
#  'citations': [{'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['C'],
#    'aulast': ['Bonneuil'],
#    'auuri': None,
#    'ayjid': 'BONNEUIL C 2006 DOSSIER ENV INRA',
#    'citations': None,
#    'contents': None,
#    'date': 2006,
#    'doi': None,
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'DOSSIER ENV INRA',
#    'pmid': None,
#    'spage': '29',
#    'topics': None,
#    'uri': None,
#    'volume': '30',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['S'],
#    'aulast': ['CECCARELLI'],
#    'auuri': None,
#    'ayjid': 'CECCARELLI S 1994 EUPHYTICA',
#    'citations': None,
#    'contents': None,
#    'date': 1994,
#    'doi': '10.1007/BF02262633',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'EUPHYTICA',
#    'pmid': None,
#    'spage': '205',
#    'topics': None,
#    'uri': None,
#    'volume': '77',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['V'],
#    'aulast': ['Chable'],
#    'auuri': None,
#    'ayjid': 'CHABLE V 2006 COURRIER ENV INRA',
#    'citations': None,
#    'contents': None,
#    'date': 2006,
#    'doi': None,
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'COURRIER ENV INRA',
#    'pmid': None,
#    'spage': '129',
#    'topics': None,
#    'uri': None,
#    'volume': '30',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['V'],
#    'aulast': ['Chable'],
#    'auuri': None,
#    'ayjid': 'CHABLE V 2009 DYNAMIQUE SAVOIRS DY',
#    'citations': None,
#    'contents': None,
#    'date': 2009,
#    'doi': None,
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'DYNAMIQUE SAVOIRS DY',
#    'pmid': None,
#    'spage': None,
#    'topics': None,
#    'uri': None,
#    'volume': '73',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['JC'],
#    'aulast': ['Dawson'],
#    'auuri': None,
#    'ayjid': 'DAWSON JC 2012 GENET RESOUR C UNPUB',
#    'citations': None,
#    'contents': None,
#    'date': 2012,
#    'doi': None,
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'GENET RESOUR C UNPUB',
#    'pmid': None,
#    'spage': None,
#    'topics': None,
#    'uri': None,
#    'volume': None,
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['GA'],
#    'aulast': ['Dyer'],
#    'auuri': None,
#    'ayjid': 'DYER GA 2008 P NATL ACAD SCI USA',
#    'citations': None,
#    'contents': None,
#    'date': 2008,
#    'doi': '10.1073/pnas.0706321105',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'P NATL ACAD SCI USA',
#    'pmid': None,
#    'spage': '470',
#    'topics': None,
#    'uri': None,
#    'volume': '105',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['MR'],
#    'aulast': ['Finckh'],
#    'auuri': None,
#    'ayjid': 'FINCKH MR 2000 AGRONOMIE',
#    'citations': None,
#    'contents': None,
#    'date': 2000,
#    'doi': '10.1051/agro:2000177',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'AGRONOMIE',
#    'pmid': None,
#    'spage': '813',
#    'topics': None,
#    'uri': None,
#    'volume': '20',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['MR'],
#    'aulast': ['Finckh'],
#    'auuri': None,
#    'ayjid': 'FINCKH MR 2008 EUR J PLANT PATHOL',
#    'citations': None,
#    'contents': None,
#    'date': 2008,
#    'doi': '10.1007/s10658-008-9273-6',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'EUR J PLANT PATHOL',
#    'pmid': None,
#    'spage': '399',
#    'topics': None,
#    'uri': None,
#    'volume': '121',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['A'],
#    'aulast': ['Ghafoor'],
#    'auuri': None,
#    'ayjid': 'GHAFOOR A 2001 FIELD CROP RES',
#    'citations': None,
#    'contents': None,
#    'date': 2001,
#    'doi': '10.1016/S0378-4290(00)00141-6',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'FIELD CROP RES',
#    'pmid': None,
#    'spage': '183',
#    'topics': None,
#    'uri': None,
#    'volume': '69',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['PhilipH'],
#    'aulast': ['Howard'],
#    'auuri': None,
#    'ayjid': 'HOWARD PHILIPH 2009 SUSTAINABILITY',
#    'citations': None,
#    'contents': None,
#    'date': 2009,
#    'doi': None,
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'Sustainability',
#    'pmid': None,
#    'spage': 'OI 10.3390/su1041266',
#    'topics': None,
#    'uri': None,
#    'volume': '1',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['HR'],
#    'aulast': ['Lafitte'],
#    'auuri': None,
#    'ayjid': 'LAFITTE HR 1997 FIELD CROP RES',
#    'citations': None,
#    'contents': None,
#    'date': 1997,
#    'doi': '10.1016/S0378-4290(96)01007-6',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'FIELD CROP RES',
#    'pmid': None,
#    'spage': '187',
#    'topics': None,
#    'uri': None,
#    'volume': '49',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['vanBuerenET'],
#    'aulast': ['Lammerts'],
#    'auuri': None,
#    'ayjid': 'LAMMERTS VANBUERENET 2010 NJAS-WAGEN J LIFE SC',
#    'citations': None,
#    'contents': None,
#    'date': 2010,
#    'doi': None,
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'NJAS-WAGEN J LIFE SC',
#    'pmid': None,
#    'spage': 'OI 10.1016/J.NJAS.2010.04.001]',
#    'topics': None,
#    'uri': None,
#    'volume': 'OI [10.1016/j.njas.2010.04.001',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['BFJ'],
#    'aulast': ['Manly'],
#    'auuri': None,
#    'ayjid': 'MANLY BFJ 1994 MULTIVARIATE STAT ME',
#    'citations': None,
#    'contents': None,
#    'date': 1994,
#    'doi': None,
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'MULTIVARIATE STAT ME',
#    'pmid': None,
#    'spage': None,
#    'topics': None,
#    'uri': None,
#    'volume': '76',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['KM'],
#    'aulast': ['Murphy'],
#    'auuri': None,
#    'ayjid': 'MURPHY KM 2007 FIELD CROP RES',
#    'citations': None,
#    'contents': None,
#    'date': 2007,
#    'doi': '10.1016/j.fcr.2007.03.011',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'FIELD CROP RES',
#    'pmid': None,
#    'spage': '172',
#    'topics': None,
#    'uri': None,
#    'volume': '102',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['AC'],
#    'aulast': ['Newton'],
#    'auuri': None,
#    'ayjid': 'NEWTON AC 2010 AGRON SUSTAIN DEV',
#    'citations': None,
#    'contents': None,
#    'date': 2010,
#    'doi': '10.1051/agro/2009032',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'AGRON SUSTAIN DEV',
#    'pmid': None,
#    'spage': '237',
#    'topics': None,
#    'uri': None,
#    'volume': '30',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['DevelopmentCoreTeam(RDC)'],
#    'aulast': ['R'],
#    'auuri': None,
#    'ayjid': 'R DEVELOPMENTCORETEAM(RDC) 2011 R LANG ENV STAT COMP',
#    'citations': None,
#    'contents': None,
#    'date': 2011,
#    'doi': None,
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'R LANG ENV STAT COMP',
#    'pmid': None,
#    'spage': None,
#    'topics': None,
#    'uri': None,
#    'volume': None,
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['InstituteInc'],
#    'aulast': ['SAS'],
#    'auuri': None,
#    'ayjid': 'SAS INSTITUTEINC 2011 SAS STAT SOFTW VERS',
#    'citations': None,
#    'contents': None,
#    'date': 2011,
#    'doi': None,
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'SAS STAT SOFTW VERS',
#    'pmid': None,
#    'spage': None,
#    'topics': None,
#    'uri': None,
#    'volume': None,
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['E'],
#    'aulast': ['Serpolay'],
#    'auuri': None,
#    'ayjid': 'SERPOLAY E 2011 ORGANIC AGRICULTURE',
#    'citations': None,
#    'contents': None,
#    'date': 2011,
#    'doi': '10.1007/s13165-011-0011-6',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'Organic Agriculture',
#    'pmid': None,
#    'spage': '127',
#    'topics': None,
#    'uri': None,
#    'volume': '1',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['M'],
#    'aulast': ['Thomas'],
#    'auuri': None,
#    'ayjid': 'THOMAS M 2012 EVOL APPL IN PRESS',
#    'citations': None,
#    'contents': None,
#    'date': 2012,
#    'doi': None,
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'EVOL APPL IN PRESS',
#    'pmid': None,
#    'spage': None,
#    'topics': None,
#    'uri': None,
#    'volume': None,
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['M'],
#    'aulast': ['Thomas'],
#    'auuri': None,
#    'ayjid': 'THOMAS M 2011 GENET RESOUR CROP EV',
#    'citations': None,
#    'contents': None,
#    'date': 2011,
#    'doi': '10.1007/s10722-011-9662-0',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'GENET RESOUR CROP EV',
#    'pmid': None,
#    'spage': '321',
#    'topics': None,
#    'uri': None,
#    'volume': '58',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['HQ'],
#    'aulast': ['Tin'],
#    'auuri': None,
#    'ayjid': 'TIN HQ 2001 EUPHYTICA',
#    'citations': None,
#    'contents': None,
#    'date': 2001,
#    'doi': '10.1023/A:1017544406975',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'EUPHYTICA',
#    'pmid': None,
#    'spage': '491',
#    'topics': None,
#    'uri': None,
#    'volume': '122',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': [' '],
#    'aulast': ['UPOV'],
#    'auuri': None,
#    'ayjid': 'UPOV   1996 GUID COND TESTS DIST',
#    'citations': None,
#    'contents': None,
#    'date': 1996,
#    'doi': None,
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'GUID COND TESTS DIST',
#    'pmid': None,
#    'spage': None,
#    'topics': None,
#    'uri': None,
#    'volume': None,
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['BuerenETL'],
#    'aulast': ['van'],
#    'auuri': None,
#    'ayjid': 'VAN BUERENETL 2010 EUPHYTICA',
#    'citations': None,
#    'contents': None,
#    'date': 2010,
#    'doi': '10.1007/s10681-010-0169-0',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'EUPHYTICA',
#    'pmid': None,
#    'spage': '51',
#    'topics': None,
#    'uri': None,
#    'volume': '175',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['M'],
#    'aulast': ['Villain'],
#    'auuri': None,
#    'ayjid': 'VILLAIN M 1999 METHODES EXPT AGRONO',
#    'citations': None,
#    'contents': None,
#    'date': 1999,
#    'doi': None,
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'METHODES EXPT AGRONO',
#    'pmid': None,
#    'spage': None,
#    'topics': None,
#    'uri': None,
#    'volume': None,
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['BrockeK'],
#    'aulast': ['vom'],
#    'auuri': None,
#    'ayjid': 'VOM BROCKEK 2003 EUPHYTICA',
#    'citations': None,
#    'contents': None,
#    'date': 2003,
#    'doi': '10.1023/A:1022830925717',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'EUPHYTICA',
#    'pmid': None,
#    'spage': '267',
#    'topics': None,
#    'uri': None,
#    'volume': '130',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['MS'],
#    'aulast': ['Wolfe'],
#    'auuri': None,
#    'ayjid': 'WOLFE MS 2000 NATURE',
#    'citations': None,
#    'contents': None,
#    'date': 2000,
#    'doi': '10.1038/35021152',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'NATURE',
#    'pmid': None,
#    'spage': '681',
#    'topics': None,
#    'uri': None,
#    'volume': '406',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['MS'],
#    'aulast': ['Wolfe'],
#    'auuri': None,
#    'ayjid': 'WOLFE MS 2008 EUPHYTICA',
#    'citations': None,
#    'contents': None,
#    'date': 2008,
#    'doi': '10.1007/s10681-008-9690-9',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'EUPHYTICA',
#    'pmid': None,
#    'spage': '323',
#    'topics': None,
#    'uri': None,
#    'volume': '163',
#    'wosid': None},
#   {'abstract': None,
#    'accession': None,
#    'atitle': None,
#    'auinit': ['YY'],
#    'aulast': ['Zhu'],
#    'auuri': None,
#    'ayjid': 'ZHU YY 2000 NATURE',
#    'citations': None,
#    'contents': None,
#    'date': 2000,
#    'doi': '10.1038/35021046',
#    'eid': None,
#    'epage': None,
#    'institutions': None,
#    'issue': None,
#    'jtitle': 'NATURE',
#    'pmid': None,
#    'spage': '718',
#    'topics': None,
#    'uri': None,
#    'volume': '406',
#    'wosid': None}],
#  'contents': None,
#  'date': 2012,
#  'doi': '10.1007/s10709-012-9646-9',
#  'eid': None,
#  'epage': '17',
#  'institutions': [['FERME MOULON, FRANCE'],
#   ['INRA SAD PAYSAGE, FRANCE'],
#   ['ECOLE INGENIEURS PURPAN, FRANCE'],
#   ['INRA SAD PAYSAGE, FRANCE'],
#   ['FERME MOULON, FRANCE'],
#   ['INRA SAD PAYSAGE, FRANCE'],
#   ['FERME MOULON, FRANCE']],
#  'issue': '1-3',
#  'jtitle': 'GENETICA',
#  'pmid': None,
#  'spage': '1',
#  'topics': None,
#  'uri': None,
#  'volume': '140',
#  'wosid': 'WOS:000305886800001'}

# %% [markdown]
# ## Indexing by time: slices

# %% [markdown]
# Often we're interested in how networks evolve over time. In Tethne, the first step to diachronic analysis is indexing, or "slicing," your ``Corpus`` by publication date. We can do this using the ``slice`` method.

# %%
MyCorpus.slice('date')

# %% [markdown]
# The default behavior is to divide your ``Paper``s up into 1-year time-periods. You can visualize the distribution of ``Paper``s over time using the ``plot_distribution`` method.

# %%
fig = MyCorpus.plot_distribution('date')

# %% [markdown]
# You can change how ``slice`` divides up your corpus temporally using the ``method``, ``window_size``, ``step_size``, and ``cumulative`` keyword arguments.

# %% [markdown]
# Here are some methods for slicing a Corpus, which you can specify using the ``method`` keyword argument.
#
# | Method           | Description
# | -----------------| --------------------------------------------------------------------------------------------------------- |
# | ``time_window``  | Slices data using a sliding time-window. Dataslices are indexed by the start of the time-window.          |
# | ``time_period``  | Slices data into time periods of equal length. Dataslices are indexed by the start of the time period.    |
#
# The main difference between the sliding time-window (``time_window``) and the time-period (``time_period``) slicing methods are whether the resulting periods can overlap. Whereas time-period slicing divides data into subsets by sequential non-overlapping time periods, subsets generated by time-window slicing can overlap.

# %% [markdown]
# **Time-period slicing, with a window-size of 4 years:**
# ![Time-period slicing, with a window-size of 4 years.](http://diging.github.io/tethne/doc/0.6.1-beta/_images/timeline.timeslice.png)

# %% [markdown]
# **Time-window slicing, with a window-size of 4 years and a step-size of 1 year:**
# ![Time-window slicing, with a window-size of 4 years and a step-size of 1 year.](http://diging.github.io/tethne/doc/0.6.1-beta/_images/timeline.timewindow.png)

# %% [markdown]
# Here's what ``plot_distribution`` looks like using a sliding time-window of 4 years:

# %%
MyCorpus.slice('date', method='time_window', window_size=4)

# %%
fig = MyCorpus.plot_distribution('date')

# %% [markdown]
# Note that it's a bit smoother, and the per-slice counts are much higher over all (max of ~700/slice, versus ~200/slice before).

# %% [markdown]
# Setting ``cumulative=True`` means that all of the ``Paper``s in the slice at time 0 will be included in the slice at time 1, and so on.

# %%
MyCorpus.slice('date', cumulative=True)

# %%
fig = MyCorpus.plot_distribution('date')

# %% [markdown]
# ## Features over time

# %% [markdown]
# Before we get to the stage of networking, we can visualize how certain features are distributed in our ``Corpus``. We'll develop the concept of features further along in these tutorials.
#
# In Tethne, a **feature** is anything (a categorical variable, scalar, etc) that can be distributed over ``Paper``s. A cited reference, for example, can be a feature. So can a word. We can think of features in terms of the presence or absence of something (e.g. a cited reference), or in terms of a quantity (e.g. the number of times the word 'organism' appears in a ``Paper``).
#
# A **featureset** is, as the name suggests, a collection of similar features. For example, we can think of all of the cited references in our ``Corpus`` as a featureset. A vocabulary of words can also be a featureset.
#
# Each ``Corpus`` has an attribute called ``features`` that holds featuresets. It's a dictionary, so you can see what featuresets your ``Corpus`` contains by calling ``Corpus.features.keys``:

# %%
MyCorpus.features.keys()

# %% [markdown]
# So far our ``Corpus`` contains only a featureset called citations. Each featureset has an index of features that it contains.

# %%
print 'There are {0} cited references in this Corpus.'.format(len(MyCorpus.features['citations']['index']))
MyCorpus.features['citations']['index'].items()[0:10]  # Only viewing the first 10 items, since there are so many.

# %% [markdown]
# We can view the distribution of a feature across the slices in our ``Corpus`` using ``plot_distribution``. This is a bit more complicated than before. We first create a dictionary that describes the feature we're interested in, and then we pass it and the ``mode='features'`` keyword argument to ``plot_distribution``.

# %%
fkwargs = {
    'featureset': 'citations',
    'feature': 'FALCONER DS 1996 INTRO QUANTITATIVE G',   # An infamous textbook on quant-gen!
    'mode': 'counts',  # The frequency of the citation in each slice.
    'normed': True,    # Normalized by the number of papers in each slice.
}

# %%
MyCorpus.slice('date')    # We'll go back to 1-year time-period slicing for now.
fig = MyCorpus.plot_distribution('date', mode='features', fkwargs=fkwargs)

# %% [markdown]
# ## Features across journals

# %% [markdown]
# We can also slice our ``Corpus`` using other elements of our data, such as journal names. To slice by journal name, try:

# %%
MyCorpus.slice('jtitle')    # jtitle stands for 'journal title'

# %% [markdown]
# We can use ``plot_distribution`` took look at the distribution of ``Paper``s across journals. In this example I use [MatPlotLib](http://matplotlib.org/)'s ``pyplot`` module to control the layout of the figure (it's pretty huge).

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(50,145))
fig = MyCorpus.plot_distribution(y_axis='jtitle', fig=fig, aspect=0.6, interpolation='none')

# %% [markdown]
# And we can view the distribution of a feature, like citations of Falconer's Quantitative Genetics textbook, across journals in a similar way:

# %%
fig = plt.figure(figsize=(50,145))
fig = MyCorpus.plot_distribution(y_axis='jtitle', fig=fig, aspect=0.6, interpolation='none', mode='features', fkwargs=fkwargs)

# %% [markdown]
# Of course, these figures are enormous and not very informative as is. The idea is that you can use this as a starting point for your analysis, and ultimately generate your own plots.
